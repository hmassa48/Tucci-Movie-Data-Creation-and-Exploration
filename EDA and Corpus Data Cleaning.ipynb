# %% [markdown]
# ## Exploratory Data Analysis
#
# Due to the assumptions made during scraping the movie datasets (that the plot synopsis found on Wikipedia accurately represents theme and actions of movie), I am going to perform some exploratory data analysis to get a better feel for the data.
#
# We want to find some obvious patterns within the data before using ML algorithms to find hidden patterns. In text data this is usually done with basic descriptive statistics. For text data we are going to do with through looking at things like common words, or

# %%
# Read in the document-term matrix
import pandas as pd

data = pd.read_pickle('Data/Tucci-dtm.pkl')
data = data.transpose()
data.head()
# Out:
# Movie Title  Prizzi's Honor  Who's That Girl (1987 film)  Monkey Shines  \
# aa                        0                            0              0
# aaron                     0                            0              0
# abandon                   0                            0              0
# abandoned                 0                            0              0
# abandoning                0                            0              0
#
# Movie Title  Slaves of New York  Fear, Anxiety & Depression  Quick Change  \
# aa                            0                           0             0
# aaron                         0                           0             0
# abandon                       0                           0             0
# abandoned                     0                           0             0
# abandoning                    0                           0             0
#
# Movie Title  Men of Respect  Billy Bathgate (film)  In the Soup  \
# aa                        0                      0            0
# aaron                     0                      0            0
# abandon                   0                      0            0
# abandoned                 0                      0            0
# abandoning                0                      0            0
#
# Movie Title  Beethoven (film)  ...  Submission (2017 film)  Show Dogs  \
# aa                          0  ...                       0          0
# aaron                       0  ...                       0          0
# abandon                     0  ...                       0          0
# abandoned                   0  ...                       0          0
# abandoning                  0  ...                       0          0
#
# Movie Title  Patient Zero (film)  A Private War  Night Hunter (2018 film)  \
# aa                             0              0                         0
# aaron                          0              0                         0
# abandon                        0              0                         0
# abandoned                      0              0                         0
# abandoning                     0              0                         0
#
# Movie Title  Worth (film)  Supernova (2020 film)  The King's Man  Jolt (film)  \
# aa                      0                      0               0            0
# aaron                   0                      0               0            0
# abandon                 0                      0               0            0
# abandoned               0                      0               0            0
# abandoning              0                      0               0            0
#
# Movie Title  Moonfall (upcoming film)
# aa                                  0
# aaron                               0
# abandon                             0
# abandoned                           0
# abandoning                          0
#
# [5 rows x 90 columns]

# %% [markdown]
# ## Most Common Words
#
# One of the exciting things about using plot descriptions is that the information should be tailored to each individual movie. However, I was worried that filler words describing movies might continuously inject themselves. Words like 'film, directed, cast'. I wanted to see if there were common words that were not important when individualizing the movie, and instead were repeated over and over when describing movies in general. To do this, I took a look at the most common words in each movie description.

# %%
# Find the top 30 words said in each movie description
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c]= list(zip(top.index, top.values))

top_dict
# Out:
# {"Prizzi's Honor": [('charley', 13),
#   ('maerose', 6),
#   ('irene', 6),
#   ('don', 4),
#   ('man', 4),
#   ('marksie', 3),
#   ('woman', 3),
#   ('wife', 3),
#   ('charleys', 3),
#   ('father', 3),
#   ('california', 2),
#   ('estranged', 2),
#   ('wedding', 2),
#   ('york', 2),
#   ('casino', 2),
#   ('marry', 2),
#   ('hit', 2),
#   ('family', 2),
#   ('fact', 2),
#   ('money', 2),
#   ('angelo', 2),
#   ('ends', 2),
#   ('business', 2),
#   ('prizzi', 2),
#   ('doesnt', 2),
#   ('nevada', 2),
#   ('eduardo', 2),
#   ('acting', 2),
#   ('new', 2),
#   ('dominic', 2)],
#  "Who's That Girl (1987 film)": [('nikki', 12),
#   ('loudon', 11),
#   ('worthington', 5),
#   ('mr', 5),
#   ('shes', 4),
#   ('murray', 4),
#   ('bus', 4),
#   ('finds', 3),
#   ('box', 3),
#   ('johnny', 3),
#   ('bell', 2),
#   ('pick', 2),
#   ('love', 2),
#   ('woman', 2),
#   ('arrested', 2),
#   ('wedding', 2),
#   ('john', 2),
#   ('cougar', 2),
#   ('years', 2),
#   ('thieves', 2),
#   ('men', 2),
#   ('theft', 2),
#   ('catch', 2),
#   ('philadelphia', 2),
#   ('vanishes', 1),
#   ('intelligent', 1),
#   ('new', 1),
#   ('plans', 1),
#   ('make', 1),
#   ('realizes', 1)],
#  'Monkey Shines': [('ella', 19),
#   ('allan', 15),
#   ('allans', 10),
#   ('melanie', 7),
#   ('geoffrey', 6),
#   ('house', 5),
#   ('romantic', 4),
#   ('having', 4),
#   ('attempts', 4),
#   ('head', 3),
#   ('kills', 3),
#   ('monkeys', 3),
#   ('surgery', 3),
#   ('bird', 3),
#   ('pentobarbitone', 2),
#   ('relationship', 2),
#   ('violent', 2),
#   ('experimental', 2),
#   ('despite', 2),
#   ('takes', 2),
#   ('condition', 2),
#   ('music', 2),
#   ('pet', 2),
#   ('neck', 2),
#   ('wiseman', 2),
#   ('summons', 2),
#   ('dr', 2),
#   ('linda', 2),
#   ('tape', 2),
#   ('arrives', 2)],
#  'Slaves of New York': [('eleanor', 6),
#   ('stash', 3),
#   ('party', 3),
#   ('designer', 2),
#   ('hat', 2),
#   ('fashion', 2),
#   ('new', 2),
#   ('ride', 1),
#   ('jan', 1),
#   ('artist', 1),
#   ('elaborate', 1),
#   ('discovers', 1),
#   ('artists', 1),
#   ('relationship', 1),
#   ('friend', 1),
#   ('dangerous', 1),
#   ('group', 1),
#   ('talk', 1),
#   ('sequencewhile', 1),
#   ('meets', 1),
#   ('crumbling', 1),
#   ('morning', 1),
#   ('city', 1),
#   ('buying', 1),
#   ('unfaithful', 1),
#   ('indifference', 1),
#   ('offers', 1),
#   ('boyfriend', 1),
#   ('invites', 1),
#   ('despite', 1)],
#  'Fear, Anxiety & Depression': [('girlfriend', 3),
#   ('sharon', 2),
#   ('iras', 2),
#   ('east', 1),
#   ('apparent', 1),
#   ('manhattan', 1),
#   ('ellis', 1),
#   ('scene', 1),
#   ('work', 1),
#   ('actress', 1),
#   ('despair', 1),
#   ('chubby', 1),
#   ('painter', 1),
#   ('castoff', 1),
#   ('vignettes', 1),
#   ('achieved', 1),
#   ('performance', 1),
#   ('village', 1),
#   ('equally', 1),
#   ('old', 1),
#   ('unsuccessful', 1),
#   ('including', 1),
#   ('friend', 1),
#   ('aspiring', 1),
#   ('jack', 1),
#   ('donny', 1),
#   ('roles', 1),
#   ('playwright', 1),
#   ('plays', 1),
#   ('artist', 1)],
#  'Quick Change': [('chief', 3),
#   ('new', 3),
#   ('phyllis', 3),
#   ('airport', 3),
#   ('trio', 3),
#   ('driver', 3),
#   ('loomis', 3),
#   ('cab', 2),
#   ('gets', 2),
#   ('york', 2),
#   ('department', 2),
#   ('grimm', 2),
#   ('bank', 2),
#   ('city', 2),
#   ('robbers', 2),
#   ('robs', 2),
#   ('away', 2),
#   ('airliner', 1),
#   ('brooklyn', 1),
#   ('broken', 1),
#   ('simple', 1),
#   ('brooklynqueens', 1),
#   ('dressed', 1),
#   ('news', 1),
#   ('newsstand', 1),
#   ('taken', 1),
#   ('english', 1),
#   ('hydrant', 1),
#   ('assistance', 1),
#   ('flight', 1)],
#  'Men of Respect': [('battaglia', 7),
#   ('family', 5),
#   ('damico', 5),
#   ('son', 3),
#   ('duffy', 3),
#   ('way', 2),
#   ('kill', 2),
#   ('woman', 2),
#   ('hit', 2),
#   ('ruthie', 2),
#   ('boss', 2),
#   ('assume', 2),
#   ('wife', 2),
#   ('ally', 2),
#   ('born', 2),
#   ('control', 2),
#   ('powerful', 2),
#   ('battaglias', 2),
#   ('harm', 1),
#   ('coronation', 1),
#   ('lieutenant', 1),
#   ('largescale', 1),
#   ('proclaims', 1),
#   ('suspects', 1),
#   ('desert', 1),
#   ('mike', 1),
#   ('drunken', 1),
#   ('reign', 1),
#   ('survives', 1),
#   ('spell', 1)],
#  'Billy Bathgate (film)': [('schultz', 9),
#   ('billy', 9),
#   ('drew', 5),
#   ('schultzs', 3),
#   ('dutch', 3),
#   ('money', 2),
#   ('luciano', 2),
#   ('gangster', 2),
#   ('court', 2),
#   ('bribe', 2),
#   ('begins', 2),
#   ('billys', 2),
#   ('beaten', 2),
#   ('falling', 2),
#   ('charges', 2),
#   ('rejected', 2),
#   ('federal', 2),
#   ('men', 2),
#   ('boy', 1),
#   ('dutchs', 1),
#   ('rap', 1),
#   ('lets', 1),
#   ('boss', 1),
#   ('day', 1),
#   ('letting', 1),
#   ('wants', 1),
#   ('natured', 1),
#   ('fired', 1),
#   ('warns', 1),
#   ('teenage', 1)],
#  'In the Soup': [('soups', 16),
#   ('thickened', 4),
#   ('clear', 3),
#   ('include', 3),
#   ('ingredients', 3),
#   ('cream', 3),
#   ('vegetables', 2),
#   ('liquid', 2),
#   ('classified', 2),
#   ('hot', 2),
#   ('french', 2),
#   ('cold', 2),
#   ('soup', 2),
#   ('used', 2),
#   ('broth', 2),
#   ('generally', 2),
#   ('broths', 1),
#   ('stock', 1),
#   ('puréed', 1),
#   ('purées', 1),
#   ('boiling', 1),
#   ('stewsin', 1),
#   ('grains', 1),
#   ('butter', 1),
#   ('classifications', 1),
#   ('rice', 1),
#   ('similar', 1),
#   ('depending', 1),
#   ('pot', 1),
#   ('potatoes', 1)],
#  'Beethoven (film)': [('beethoven', 15),
#   ('george', 10),
#   ('dr', 8),
#   ('varnick', 7),
#   ('newtons', 6),
#   ('euthanized', 5),
#   ('dogs', 5),
#   ('family', 4),
#   ('varnicks', 4),
#   ('dog', 4),
#   ('vernon', 3),
#   ('st', 3),
#   ('ted', 3),
#   ('home', 3),
#   ('ryce', 3),
#   ('newton', 3),
#   ('emily', 3),
#   ('harvey', 3),
#   ('alice', 2),
#   ('bernards', 2),
#   ('tells', 2),
#   ('office', 2),
#   ('fake', 2),
#   ('fears', 2),
#   ('captive', 2),
#   ('familys', 2),
#   ('animal', 2),
#   ('takes', 2),
#   ('car', 2),
#   ('escape', 2)],
#  'Prelude to a Kiss (film)': [('soul', 3),
#   ('rita', 3),
#   ('life', 3),
#   ('peter', 3),
#   ('afraid', 2),
#   ('julius', 2),
#   ('fears', 2),
#   ('wanted', 2),
#   ('elderly', 1),
#   ('beautiful', 1),
#   ('spirits', 1),
#   ('convincing', 1),
#   ('return', 1),
#   ('aspiring', 1),
#   ('freespirited', 1),
#   ('anymore', 1),
#   ('wedding', 1),
#   ('old', 1),
#   ('chicago', 1),
#   ('permission', 1),
#   ('house', 1),
#   ('love', 1),
#   ('residing', 1),
#   ('man', 1),
#   ('switch', 1),
#   ('sees', 1),
#   ('designer', 1),
#   ('approached', 1),
#   ('boyle', 1),
#   ('liberal', 1)],
#  'The Public Eye (film)': [('kay', 3),
#   ('bernzy', 3),
#   ('police', 3),
#   ('mob', 3),
#   ('great', 2),
#   ('bernstein', 2),
#   ('sal', 2),
#   ('place', 2),
#   ('races', 1),
#   ('nabler', 1),
#   ('life', 1),
#   ('photographs', 1),
#   ('photographer', 1),
#   ('rationing', 1),
#   ('waits', 1),
#   ('dashboard', 1),
#   ('quickly', 1),
#   ('federal', 1),
#   ('local', 1),
#   ('darkroom', 1),
#   ('interested', 1),
#   ('muscling', 1),
#   ('vivid', 1),
#   ('murdered', 1),
#   ('radio', 1),
#   ('danger', 1),
#   ('war', 1),
#   ('death', 1),
#   ('involving', 1),
#   ('suspect', 1)],
#  'Undercover Blues': [('novacek', 11),
#   ('jane', 11),
#   ('jeff', 7),
#   ('daughter', 5),
#   ('blues', 4),
#   ('explosive', 4),
#   ('muerte', 4),
#   ('leave', 4),
#   ('sawyer', 4),
#   ('orleans', 3),
#   ('new', 3),
#   ('helicopter', 2),
#   ('novaceks', 2),
#   ('mugging', 2),
#   ('attempts', 2),
#   ('tracker', 2),
#   ('frank', 2),
#   ('life', 2),
#   ('boat', 2),
#   ('away', 2),
#   ('case', 2),
#   ('follows', 2),
#   ('louise', 2),
#   ('continually', 2),
#   ('called', 2),
#   ('maternity', 2),
#   ('looking', 2),
#   ('mug', 1),
#   ('rumored', 1),
#   ('grasp', 1)],
#  'The Pelican Brief (film)': [('darby', 10),
#   ('grantham', 8),
#   ('mattiece', 8),
#   ('killed', 5),
#   ('brief', 5),
#   ('justices', 5),
#   ('fbi', 4),
#   ('gives', 4),
#   ('oil', 4),
#   ('president', 4),
#   ('white', 4),
#   ('washington', 4),
#   ('court', 4),
#   ('darbys', 4),
#   ('verheek', 4),
#   ('khamel', 4),
#   ('contacts', 3),
#   ('law', 3),
#   ('information', 3),
#   ('box', 3),
#   ('theory', 3),
#   ('meet', 3),
#   ('confirms', 2),
#   ('unknown', 2),
#   ('attacked', 2),
#   ('blazevich', 2),
#   ('director', 2),
#   ('manages', 2),
#   ('turn', 2),
#   ('accurate', 2)],
#  'It Could Happen to You (1994 film)': [('yvonne', 8),
#   ('charlie', 7),
#   ('muriel', 7),
#   ('diner', 5),
#   ('money', 5),
#   ('new', 4),
#   ('gets', 4),
#   ('divorce', 3),
#   ('job', 3),
#   ('york', 3),
#   ('eddie', 3),
#   ('man', 3),
#   ('day', 3),
#   ('doesnt', 3),
#   ('lottery', 3),
#   ('apartment', 3),
#   ('end', 2),
#   ('ticket', 2),
#   ('million', 2),
#   ('force', 2),
#   ('tip', 2),
#   ('works', 2),
#   ('account', 2),
#   ('court', 2),
#   ('pay', 2),
#   ('jack', 2),
#   ('gross', 2),
#   ('waitress', 2),
#   ('husband', 2),
#   ('just', 2)],
#  'Mrs. Parker and the Vicious Circle': [('film', 5),
#   ('benchley', 2),
#   ('critics', 2),
#   ('shawn', 2),
#   ('algonquin', 2),
#   ('leigh', 2),
#   ('parker', 2),
#   ('crowninshield', 2),
#   ('editor', 2),
#   ('rudolph', 2),
#   ('humorist', 1),
#   ('biographical', 1),
#   ('won', 1),
#   ('official', 1),
#   ('washington', 1),
#   ('selection', 1),
#   ('wallace', 1),
#   ('actresspeter', 1),
#   ('vicious', 1),
#   ('round', 1),
#   ('national', 1),
#   ('actors', 1),
#   ('actor', 1),
#   ('critical', 1),
#   ('met', 1),
#   ('frank', 1),
#   ('circle', 1),
#   ('palme', 1),
#   ('grandson', 1),
#   ('manhattans', 1)],
#  'Somebody to Love (1994 film)': [('film', 2),
#   ('love', 1),
#   ('directed', 1),
#   ('romanticdrama', 1),
#   ('cabiria', 1),
#   ('fellinis', 1),
#   ('competition', 1),
#   ('somebody', 1),
#   ('festival', 1),
#   ('inspired', 1),
#   ('nights', 1),
#   ('venice', 1),
#   ('international', 1),
#   ('federico', 1),
#   ('rockwell', 1),
#   ('american', 1),
#   ('entered', 1),
#   ('alexandre', 1),
#   ('fate', 0),
#   ('fault', 0),
#   ('faucet', 0),
#   ('fancy', 0),
#   ('fans', 0),
#   ('fantasies', 0),
#   ('fantasizes', 0),
#   ('fathers', 0),
#   ('far', 0),
#   ('farm', 0),
#   ('fascinated', 0),
#   ('farthe', 0)],
#  'Jury Duty (film)': [('tommy', 16),
#   ('frank', 7),
#   ('jurors', 7),
#   ('finds', 6),
#   ('monica', 6),
#   ('evidence', 5),
#   ('bishop', 5),
#   ('jury', 4),
#   ('carl', 3),
#   ('fast', 3),
#   ('polystyrene', 3),
#   ('food', 3),
#   ('wayne', 3),
#   ('room', 3),
#   ('guilty', 3),
#   ('suite', 3),
#   ('man', 3),
#   ('peanut', 3),
#   ('later', 3),
#   ('decides', 2),
#   ('case', 2),
#   ('school', 2),
#   ('goes', 2),
#   ('seeing', 2),
#   ('erotic', 2),
#   ('staying', 2),
#   ('library', 2),
#   ('away', 2),
#   ('park', 2),
#   ('help', 2)],
#  'Kiss of Death (1995 film)': [('jimmy', 22),
#   ('junior', 17),
#   ('little', 15),
#   ('ronnie', 12),
#   ('bev', 7),
#   ('cars', 6),
#   ('brown', 5),
#   ('browns', 5),
#   ('jimmys', 5),
#   ('death', 5),
#   ('ronnies', 5),
#   ('rosie', 4),
#   ('stolen', 4),
#   ('meeting', 4),
#   ('daughter', 4),
#   ('car', 4),
#   ('cakes', 3),
#   ('baby', 3),
#   ('city', 3),
#   ('just', 3),
#   ('police', 3),
#   ('bevs', 3),
#   ('takes', 3),
#   ('omar', 3),
#   ('goes', 2),
#   ('arrest', 2),
#   ('returns', 2),
#   ('shop', 2),
#   ('arrive', 2),
#   ('navy', 2)],
#  'Sex and the Other Man': [('film', 3),
#   ('anton', 1),
#   ('stanley', 1),
#   ('kari', 1),
#   ('conrad', 1),
#   ('sankothe', 1),
#   ('wuhrer', 1),
#   ('known', 1),
#   ('tucci', 1),
#   ('eldard', 1),
#   ('drama', 1),
#   ('sex', 1),
#   ('starring', 1),
#   ('composed', 1),
#   ('ron', 1),
#   ('man', 1),
#   ('roles', 1),
#   ('comedy', 1),
#   ('slovin', 1),
#   ('lead', 1),
#   ('karl', 1),
#   ('goode', 1),
#   ('music', 1),
#   ('directed', 1),
#   ('american', 1),
#   ('captive', 1),
#   ('festival', 0),
#   ('fantasies', 0),
#   ('famed', 0),
#   ('family', 0)],
#  'A Modern Affair': [('affair', 4),
#   ('modern', 3),
#   ('film', 3),
#   ('pregnant', 3),
#   ('woman', 3),
#   ('sperm', 3),
#   ('grace', 3),
#   ('intimacy', 2),
#   ('identity', 2),
#   ('going', 2),
#   ('man', 2),
#   ('world', 2),
#   ('commitment', 2),
#   ('father', 2),
#   ('lisa', 2),
#   ('love', 2),
#   ('stanley', 2),
#   ('baby', 2),
#   ('bank', 2),
#   ('eichhorn', 2),
#   ('feature', 2),
#   ('elaine', 2),
#   ('tucci', 2),
#   ('advice', 1),
#   ('goes', 1),
#   ('rhodes', 1),
#   ('begins', 1),
#   ('parenthooda', 1),
#   ('rocked', 1),
#   ('new', 1)],
#  'The Daytrippers': [('family', 2),
#   ('parents', 1),
#   ('husband', 1),
#   ('anne', 1),
#   ('boyfriend', 1),
#   ('sister', 1),
#   ('island', 1),
#   ('tucci', 1),
#   ('rita', 1),
#   ('carl', 1),
#   ('love', 1),
#   ('prove', 1),
#   ('affair', 1),
#   ('confront', 1),
#   ('discovers', 1),
#   ('schreiber', 1),
#   ('including', 1),
#   ('posey', 1),
#   ('louis', 1),
#   ('new', 1),
#   ('davis', 1),
#   ('stanley', 1),
#   ('parker', 1),
#   ('york', 1),
#   ('jos', 1),
#   ('station', 1),
#   ('having', 1),
#   ('hope', 1),
#   ('mcnamara', 1),
#   ('pat', 1)],
#  'Big Night': [('secondo', 10),
#   ('primo', 6),
#   ('restaurant', 6),
#   ('food', 6),
#   ('pascal', 6),
#   ('brothers', 5),
#   ('prima', 3),
#   ('brother', 3),
#   ('paradise', 3),
#   ('phyllis', 3),
#   ('gabriella', 3),
#   ('work', 3),
#   ('primos', 2),
#   ('singer', 2),
#   ('singers', 2),
#   ('magnificent', 2),
#   ('louis', 2),
#   ('admits', 2),
#   ('hours', 2),
#   ('secondos', 2),
#   ('return', 2),
#   ('dish', 2),
#   ('italian', 2),
#   ('reporter', 2),
#   ('despite', 2),
#   ('beach', 2),
#   ('called', 2),
#   ('offer', 2),
#   ('new', 2),
#   ('refuses', 2)],
#  'Deconstructing Harry': [('harry', 26),
#   ('richard', 6),
#   ('fay', 6),
#   ('harrys', 5),
#   ('ceremony', 5),
#   ('based', 4),
#   ('novel', 4),
#   ('lucy', 4),
#   ('asks', 4),
#   ('story', 4),
#   ('hilliard', 4),
#   ('cookie', 3),
#   ('gun', 3),
#   ('university', 3),
#   ('universitys', 2),
#   ('billy', 2),
#   ('larry', 2),
#   ('accompany', 2),
#   ('writing', 2),
#   ('fictional', 2),
#   ('character', 2),
#   ('latest', 2),
#   ('gets', 2),
#   ('crystal', 2),
#   ('sexobsessed', 2),
#   ('man', 2),
#   ('husband', 2),
#   ('wedding', 2),
#   ('begins', 2),
#   ('having', 2)],
#  'The Alarmist (film)': [('film', 2),
#   ('written', 2),
#   ('keith', 1),
#   ('crime', 1),
#   ('known', 1),
#   ('tucci', 1),
#   ('wartime', 1),
#   ('reddin', 1),
#   ('starring', 1),
#   ('adaptation', 1),
#   ('play', 1),
#   ('kate', 1),
#   ('dunsky', 1),
#   ('comedy', 1),
#   ('ryan', 1),
#   ('alarmist', 1),
#   ('david', 1),
#   ('reynolds', 1),
#   ('arquette', 1),
#   ('directed', 1),
#   ('life', 1),
#   ('evan', 1),
#   ('stanley', 1),
#   ('capshaw', 1),
#   ('fashionconscious', 0),
#   ('father', 0),
#   ('fantasies', 0),
#   ('fantasizes', 0),
#   ('fatherinlaw', 0),
#   ('fatherat', 0)],
#  'A Life Less Ordinary': [('celine', 28),
#   ('robert', 24),
#   ('jackson', 14),
#   ('oreilly', 12),
#   ('naville', 6),
#   ('love', 6),
#   ('money', 5),
#   ('runs', 5),
#   ('mayhew', 4),
#   ('gabriel', 4),
#   ('bar', 4),
#   ('roberts', 4),
#   ('case', 4),
#   ('knocks', 4),
#   ('angels', 4),
#   ('drive', 3),
#   ('elliott', 3),
#   ('shoots', 3),
#   ('tells', 3),
#   ('woods', 3),
#   ('car', 3),
#   ('head', 3),
#   ('cabin', 3),
#   ('poem', 3),
#   ('decides', 3),
#   ('daughter', 2),
#   ('says', 2),
#   ('heart', 2),
#   ('gun', 2),
#   ('file', 2)],
#  'The Eighteenth Angel': [('etruscan', 4),
#   ('old', 4),
#   ('daughter', 3),
#   ('girls', 3),
#   ('building', 3),
#   ('man', 3),
#   ('prophecy', 3),
#   ('scientist', 3),
#   ('father', 3),
#   ('girl', 2),
#   ('dead', 2),
#   ('perfect', 2),
#   ('just', 2),
#   ('america', 2),
#   ('experiments', 2),
#   ('eighteen', 2),
#   ('mysterious', 2),
#   ('mother', 2),
#   ('turns', 2),
#   ('biologically', 1),
#   ('artificially', 1),
#   ('beings', 1),
#   ('rise', 1),
#   ('wife', 1),
#   ('begins', 1),
#   ('secret', 1),
#   ('picture', 1),
#   ('north', 1),
#   ('physically', 1),
#   ('sect', 1)],
#  'Montana (1998 film)': [('kitty', 2),
#   ('claire', 2),
#   ('boss', 2),
#   ('targeted', 1),
#   ('retrieving', 1),
#   ('hit', 1),
#   ('professional', 1),
#   ('kyra', 1),
#   ('girlfriend', 1),
#   ('gives', 1),
#   ('woman', 1),
#   ('sedgwick', 1),
#   ('stop', 1),
#   ('ethan', 1),
#   ('robin', 1),
#   ('tunney', 1),
#   ('embry', 1),
#   ('tracks', 1),
#   ('coltrane', 1),
#   ('incompetent', 1),
#   ('level', 1),
#   ('low', 1),
#   ('son', 1),
#   ('runaway', 1),
#   ('task', 1),
#   ('robbie', 1),
#   ('unable', 1),
#   ('organization', 1),
#   ('killing', 1),
#   ('fashion', 0)],
#  'The Impostors': [('burtom', 2),
#   ('actor', 1),
#   ('tennis', 1),
#   ('professional', 1),
#   ('drunken', 1),
#   ('stowaways', 1),
#   ('diverse', 1),
#   ('jeremy', 1),
#   ('crooner', 1),
#   ('hide', 1),
#   ('city', 1),
#   ('happy', 1),
#   ('buscemi', 1),
#   ('language', 1),
#   ('duo', 1),
#   ('ocean', 1),
#   ('named', 1),
#   ('acting', 1),
#   ('billy', 1),
#   ('moremistaken', 1),
#   ('franks', 1),
#   ('bomber', 1),
#   ('confrontation', 1),
#   ('sobs', 1),
#   ('ensue', 1),
#   ('swindles', 1),
#   ('practicing', 1),
#   ('platt', 1),
#   ('stanley', 1),
#   ('mad', 1)],
#  "A Midsummer Night's Dream (1999 film)": [('titania', 4),
#   ('oberon', 4),
#   ('demetrius', 4),
#   ('hermia', 4),
#   ('lysander', 4),
#   ('helena', 3),
#   ('forest', 3),
#   ('puck', 2),
#   ('tragedy', 2),
#   ('queen', 2),
#   ('troupe', 2),
#   ('young', 2),
#   ('duke', 2),
#   ('lovers', 2),
#   ('fairies', 2),
#   ('play', 2),
#   ('love', 2),
#   ('actors', 2),
#   ('desperately', 1),
#   ('seen', 1),
#   ('bower', 1),
#   ('tires', 1),
#   ('final', 1),
#   ('plan', 1),
#   ('wander', 1),
#   ('famously', 1),
#   ('rehearsal', 1),
#   ('athena', 1),
#   ('woos', 1),
#   ('unintentionally', 1)],
#  'In Too Deep (1999 film)': [('cole', 38),
#   ('gittens', 26),
#   ('undercover', 15),
#   ('reid', 7),
#   ('dambrosio', 7),
#   ('crew', 7),
#   ('eventually', 6),
#   ('begins', 5),
#   ('myra', 5),
#   ('breezy', 5),
#   ('work', 4),
#   ('man', 4),
#   ('police', 4),
#   ('scott', 4),
#   ('superiors', 4),
#   ('god', 4),
#   ('deep', 3),
#   ('starts', 3),
#   ('officers', 3),
#   ('identity', 3),
#   ('unhinged', 3),
#   ('coles', 3),
#   ('organization', 3),
#   ('cop', 3),
#   ('members', 3),
#   ('drug', 3),
#   ('far', 3),
#   ('connelly', 3),
#   ('empire', 3),
#   ('goes', 3)],
#  "Joe Gould's Secret (film)": [('gould', 5),
#   ('mitchell', 3),
#   ('village', 2),
#   ('joe', 2),
#   ('demanding', 2),
#   ('opus', 1),
#   ('bearded', 1),
#   ('portrait', 1),
#   ('mans', 1),
#   ('colorful', 1),
#   ('portfolio', 1),
#   ('time', 1),
#   ('people', 1),
#   ('perceptive', 1),
#   ('times', 1),
#   ('manhattan', 1),
#   ('wanders', 1),
#   ('life', 1),
#   ('sweet', 1),
#   ('daughters', 1),
#   ('obnoxious', 1),
#   ('greenwich', 1),
#   ('hes', 1),
#   ('collecting', 1),
#   ('support', 1),
#   ('merely', 1),
#   ('occasional', 1),
#   ('founder', 1),
#   ('shop', 1),
#   ('actually', 1)],
#  "America's Sweethearts": [('eddie', 20),
#   ('gwen', 19),
#   ('kiki', 12),
#   ('lee', 8),
#   ('film', 8),
#   ('press', 7),
#   ('hector', 6),
#   ('weidmann', 5),
#   ('junket', 4),
#   ('time', 4),
#   ('gwens', 4),
#   ('eddies', 3),
#   ('convince', 3),
#   ('affair', 3),
#   ('love', 3),
#   ('tells', 3),
#   ('believes', 3),
#   ('assistant', 3),
#   ('career', 3),
#   ('refuses', 2),
#   ('stories', 2),
#   ('work', 2),
#   ('studios', 2),
#   ('movie', 2),
#   ('public', 2),
#   ('portrayed', 2),
#   ('weidmanns', 2),
#   ('leave', 2),
#   ('relationship', 2),
#   ('crew', 2)],
#  'The Whole Shebang (film)': [('bridget', 2),
#   ('film', 2),
#   ('tucci', 1),
#   ('retired', 1),
#   ('george', 1),
#   ('starring', 1),
#   ('role', 1),
#   ('appeared', 1),
#   ('movie', 1),
#   ('movies', 1),
#   ('television', 1),
#   ('comedy', 1),
#   ('final', 1),
#   ('stanley', 1),
#   ('americancanadian', 1),
#   ('couple', 1),
#   ('directed', 1),
#   ('romantic', 1),
#   ('zaloom', 1),
#   ('theatrical', 1),
#   ('date', 1),
#   ('fonda', 1),
#   ('fondas', 1),
#   ('shebang', 1),
#   ('giancarlo', 1),
#   ('gianninithis', 1),
#   ('written', 1),
#   ('fantasies', 0),
#   ('fans', 0),
#   ('fantasizes', 0)],
#  'Big Trouble (2002 film)': [('eliot', 9),
#   ('arthur', 8),
#   ('bomb', 7),
#   ('snake', 7),
#   ('puggy', 6),
#   ('plane', 6),
#   ('jenny', 6),
#   ('matt', 5),
#   ('eddie', 5),
#   ('herk', 4),
#   ('airport', 4),
#   ('monica', 4),
#   ('criminals', 4),
#   ('matts', 4),
#   ('romero', 3),
#   ('anne', 3),
#   ('agents', 3),
#   ('miami', 3),
#   ('hitmen', 3),
#   ('fbi', 3),
#   ('walter', 3),
#   ('nuclear', 3),
#   ('home', 3),
#   ('suitcase', 3),
#   ('called', 3),
#   ('case', 2),
#   ('escape', 2),
#   ('door', 2),
#   ('handcuffed', 2),
#   ('gun', 2)],
#  'Road to Perdition': [('sullivan', 32),
#   ('rooney', 13),
#   ('connor', 13),
#   ('michael', 11),
#   ('maguire', 10),
#   ('son', 9),
#   ('jr', 8),
#   ('kill', 5),
#   ('home', 4),
#   ('kills', 4),
#   ('mcgovern', 4),
#   ('father', 4),
#   ('gun', 4),
#   ('fathers', 4),
#   ('rooneys', 3),
#   ('couple', 3),
#   ('sons', 3),
#   ('men', 3),
#   ('shoots', 3),
#   ('nitti', 3),
#   ('calvino', 3),
#   ('sends', 3),
#   ('sullivans', 3),
#   ('rance', 3),
#   ('farm', 3),
#   ('money', 3),
#   ('drives', 2),
#   ('capones', 2),
#   ('killed', 2),
#   ('returns', 2)],
#  'Maid in Manhattan': [('marisa', 19),
#   ('chris', 15),
#   ('hotel', 11),
#   ('caroline', 9),
#   ('ty', 7),
#   ('room', 5),
#   ('asks', 4),
#   ('lane', 4),
#   ('management', 4),
#   ('stephanie', 4),
#   ('time', 4),
#   ('lionel', 3),
#   ('real', 3),
#   ('maid', 3),
#   ('shows', 2),
#   ('spends', 2),
#   ('affair', 2),
#   ('staff', 2),
#   ('promoted', 2),
#   ('nixon', 2),
#   ('lunch', 2),
#   ('coat', 2),
#   ('mother', 2),
#   ('wants', 2),
#   ('jerry', 2),
#   ('dinner', 2),
#   ('school', 2),
#   ('spend', 2),
#   ('end', 2),
#   ('richard', 2)],
#  'The Core': [('core', 8),
#   ('keyes', 8),
#   ('virgil', 6),
#   ('team', 5),
#   ('power', 5),
#   ('finch', 5),
#   ('compartment', 5),
#   ('destini', 4),
#   ('restart', 4),
#   ('rotation', 4),
#   ('zimsky', 4),
#   ('dr', 4),
#   ('nuclear', 3),
#   ('charges', 3),
#   ('time', 3),
#   ('vessel', 3),
#   ('energy', 3),
#   ('surface', 3),
#   ('cores', 3),
#   ('field', 3),
#   ('childs', 3),
#   ('gigantic', 2),
#   ('pressure', 2),
#   ('previously', 2),
#   ('lead', 2),
#   ('detonation', 2),
#   ('geode', 2),
#   ('world', 2),
#   ('nearby', 2),
#   ('thought', 2)],
#  'Spin (2004 film)': [('film', 4),
#   ('released', 2),
#   ('spin', 2),
#   ('paula', 1),
#   ('american', 1),
#   ('starring', 1),
#   ('adapted', 1),
#   ('festival', 1),
#   ('axinn', 1),
#   ('market', 1),
#   ('heartland', 1),
#   ('stanley', 1),
#   ('states', 1),
#   ('united', 1),
#   ('won', 1),
#   ('novel', 1),
#   ('drama', 1),
#   ('tucci', 1),
#   ('limited', 1),
#   ('rubén', 1),
#   ('merriman', 1),
#   ('awards', 1),
#   ('october', 1),
#   ('donald', 1),
#   ('delany', 1),
#   ('cannes', 1),
#   ('blades', 1),
#   ('garcés', 1),
#   ('dana', 1),
#   ('everett', 1)],
#  'The Life and Death of Peter Sellers': [('film', 5),
#   ('success', 3),
#   ('life', 2),
#   ('shows', 2),
#   ('characters', 2),
#   ('eventually', 2),
#   ('personality', 2),
#   ('complex', 1),
#   ('identity', 1),
#   ('dependent', 1),
#   ('concealed', 1),
#   ('self', 1),
#   ('swings', 1),
#   ('domineering', 1),
#   ('relationships', 1),
#   ('gift', 1),
#   ('relatively', 1),
#   ('makes', 1),
#   ('peter', 1),
#   ('used', 1),
#   ('sellers', 1),
#   ('method', 1),
#   ('wore', 1),
#   ('actorthe', 1),
#   ('actors', 1),
#   ('actor', 1),
#   ('unhappy', 1),
#   ('merged', 1),
#   ('destructive', 1),
#   ('selflearned', 1)],
#  'The Terminal': [('viktor', 19),
#   ('dixon', 7),
#   ('airport', 6),
#   ('amelia', 6),
#   ('home', 5),
#   ('krakozhia', 4),
#   ('arrives', 3),
#   ('taxi', 3),
#   ('leave', 3),
#   ('new', 3),
#   ('newspaper', 2),
#   ('viktors', 2),
#   ('gets', 2),
#   ('getting', 2),
#   ('peanut', 2),
#   ('finally', 2),
#   ('planters', 2),
#   ('golson', 2),
#   ('gupta', 2),
#   ('customs', 2),
#   ('passport', 2),
#   ('longer', 2),
#   ('york', 2),
#   ('visa', 2),
#   ('man', 2),
#   ('terminal', 2),
#   ('day', 2),
#   ('return', 2),
#   ('renovation', 2),
#   ('contractor', 2)],
#  'Shall We Dance? (2004 film)': [('john', 17),
#   ('dance', 10),
#   ('beverly', 6),
#   ('paulina', 5),
#   ('dancing', 5),
#   ('bobbie', 4),
#   ('wife', 4),
#   ('dances', 4),
#   ('new', 3),
#   ('partner', 3),
#   ('link', 3),
#   ('competition', 3),
#   ('studio', 3),
#   ('lessons', 3),
#   ('lost', 3),
#   ('chic', 2),
#   ('investigator', 2),
#   ('party', 2),
#   ('vern', 2),
#   ('latin', 2),
#   ('loves', 2),
#   ('family', 2),
#   ('goes', 2),
#   ('home', 2),
#   ('miss', 2),
#   ('finds', 2),
#   ('sees', 2),
#   ('meet', 2),
#   ('private', 2),
#   ('just', 2)],
#  'Robots (2005 film)': [('rodney', 21),
#   ('bigweld', 20),
#   ('ratchet', 8),
#   ('industries', 7),
#   ('herb', 7),
#   ('rusties', 7),
#   ('cappy', 7),
#   ('fender', 6),
#   ('ratchets', 5),
#   ('parts', 5),
#   ('spare', 5),
#   ('outmodes', 5),
#   ('gasket', 5),
#   ('wonderbot', 4),
#   ('vehicle', 4),
#   ('shop', 4),
#   ('town', 4),
#   ('chop', 4),
#   ('bigwelds', 4),
#   ('robots', 4),
#   ('city', 3),
#   ('robot', 3),
#   ('make', 3),
#   ('upgrades', 3),
#   ('rivet', 3),
#   ('father', 2),
#   ('security', 2),
#   ('populated', 2),
#   ('need', 2),
#   ('unable', 2)],
#  'Lucky Number Slevin': [('slevin', 32),
#   ('goodkat', 23),
#   ('boss', 13),
#   ('rabbi', 9),
#   ('lindsey', 9),
#   ('killed', 7),
#   ('son', 7),
#   ('fairy', 7),
#   ('nick', 7),
#   ('apartment', 6),
#   ('young', 6),
#   ('nicks', 5),
#   ('kill', 5),
#   ('brikowski', 5),
#   ('revealed', 5),
#   ('max', 5),
#   ('city', 4),
#   ('time', 4),
#   ('years', 4),
#   ('bet', 4),
#   ('henry', 4),
#   ('murdered', 4),
#   ('shoots', 3),
#   ('man', 3),
#   ('gambling', 3),
#   ('mob', 3),
#   ('rabbis', 3),
#   ('bookies', 3),
#   ('later', 3),
#   ('identity', 3)],
#  'The Devil Wears Prada (film)': [('andy', 22),
#   ('miranda', 15),
#   ('emily', 10),
#   ('job', 8),
#   ('runway', 6),
#   ('paris', 5),
#   ('mirandas', 5),
#   ('fashion', 5),
#   ('tells', 4),
#   ('nate', 4),
#   ('later', 4),
#   ('nigel', 4),
#   ('assistant', 4),
#   ('new', 4),
#   ('begins', 4),
#   ('car', 4),
#   ('director', 3),
#   ('starts', 3),
#   ('day', 2),
#   ('creative', 2),
#   ('jacqueline', 2),
#   ('editor', 2),
#   ('does', 2),
#   ('writer', 2),
#   ('accepted', 2),
#   ('replace', 2),
#   ('leaving', 2),
#   ('dress', 2),
#   ('chef', 2),
#   ('holt', 2)],
#  'The Hoax': [('passed', 1),
#   ('urban', 1),
#   ('rumors', 1),
#   ('day', 1),
#   ('hoax', 1),
#   ('truth', 1),
#   ('judgment', 1),
#   ('jokes', 1),
#   ('distinguishable', 1),
#   ('observation', 1),
#   ('legends', 1),
#   ('masquerade', 1),
#   ('believers', 1),
#   ('april', 1),
#   ('falsehood', 1),
#   ('fabricated', 1),
#   ('pseudosciences', 1),
#   ('faith', 1),
#   ('fools', 1),
#   ('good', 1),
#   ('errors', 1),
#   ('deliberately', 1),
#   ('events', 1),
#   ('fenerman', 0),
#   ('fancy', 0),
#   ('fame', 0),
#   ('fiennes', 0),
#   ('field', 0),
#   ('famed', 0),
#   ('family', 0)],
#  'Four Last Songs (film)': [('concert', 3),
#   ('veronica', 3),
#   ('island', 2),
#   ('girlfriend', 2),
#   ('life', 2),
#   ('local', 2),
#   ('piano', 2),
#   ('larry', 2),
#   ('ago', 1),
#   ('widow', 1),
#   ('stanley', 1),
#   ('unsatisfied', 1),
#   ('blue', 1),
#   ('rising', 1),
#   ('secluded', 1),
#   ('miranda', 1),
#   ('healed', 1),
#   ('leads', 1),
#   ('plots', 1),
#   ('plays', 1),
#   ('player', 1),
#   ('play', 1),
#   ('spouses', 1),
#   ('chosen', 1),
#   ('dedicated', 1),
#   ('sebastian', 1),
#   ('latches', 1),
#   ('hynes', 1),
#   ('late', 1),
#   ('surrounding', 1)],
#  'Blind Date (2007 film)': [('film', 5),
#   ('sundance', 1),
#   ('drama', 1),
#   ('remake', 1),
#   ('late', 1),
#   ('gogh', 1),
#   ('van', 1),
#   ('cowrote', 1),
#   ('screenplay', 1),
#   ('stars', 1),
#   ('schechter', 1),
#   ('tucci', 1),
#   ('stanley', 1),
#   ('david', 1),
#   ('date', 1),
#   ('theo', 1),
#   ('festival', 1),
#   ('dutch', 1),
#   ('premiered', 1),
#   ('blind', 1),
#   ('director', 1),
#   ('directed', 1),
#   ('evidence', 0),
#   ('fantasizes', 0),
#   ('farm', 0),
#   ('farthe', 0),
#   ('fascinated', 0),
#   ('fascination', 0),
#   ('eventual', 0),
#   ('fashion', 0)],
#  'Kit Kittredge: An American Girl': [('kit', 9),
#   ('homeless', 5),
#   ('mr', 4),
#   ('mother', 3),
#   ('countee', 3),
#   ('robberies', 2),
#   ('father', 2),
#   ('jungle', 2),
#   ('gibson', 2),
#   ('miss', 2),
#   ('kits', 2),
#   ('newspaper', 2),
#   ('writes', 2),
#   ('berk', 2),
#   ('wills', 2),
#   ('dog', 1),
#   ('boy', 1),
#   ('box', 1),
#   ('suspect', 1),
#   ('unfolds', 1),
#   ('footprint', 1),
#   ('clear', 1),
#   ('time', 1),
#   ('foreclosed', 1),
#   ('bedroom', 1),
#   ('live', 1),
#   ('finds', 1),
#   ('food', 1),
#   ('sells', 1),
#   ('erie', 1)],
#  'Space Chimps': [('ham', 12),
#   ('titan', 8),
#   ('probe', 8),
#   ('luna', 7),
#   ('ship', 6),
#   ('zartog', 6),
#   ('help', 5),
#   ('kilowatt', 5),
#   ('space', 5),
#   ('chimps', 5),
#   ('planet', 4),
#   ('just', 4),
#   ('earth', 3),
#   ('inhabitants', 3),
#   ('palace', 3),
#   ('scientists', 3),
#   ('way', 3),
#   ('wormhole', 3),
#   ('pressure', 3),
#   ('escape', 3),
#   ('houston', 3),
#   ('planets', 2),
#   ('comet', 2),
#   ('use', 2),
#   ('monster', 2),
#   ('loss', 2),
#   ('tells', 2),
#   ('task', 2),
#   ('pass', 2),
#   ('explore', 2)],
#  'Swing Vote (2008 film)': [('vote', 5),
#   ('bud', 5),
#   ('candidates', 4),
#   ('life', 3),
#   ('election', 3),
#   ('new', 3),
#   ('set', 2),
#   ('mexico', 2),
#   ('voting', 2),
#   ('molly', 2),
#   ('stand', 2),
#   ('ballot', 2),
#   ('manager', 2),
#   ('film', 2),
#   ('day', 2),
#   ('electoral', 2),
#   ('campaign', 2),
#   ('candidate', 2),
#   ('gets', 2),
#   ('mail', 1),
#   ('progresses', 1),
#   ('majority', 1),
#   ('ends', 1),
#   ('flipflop', 1),
#   ('energize', 1),
#   ('prolife', 1),
#   ('major', 1),
#   ('tactics', 1),
#   ('chooses', 1),
#   ('head', 1)],
#  'What Just Happened (2008 film)': [('ben', 10),
#   ('lou', 5),
#   ('jeremy', 5),
#   ('film', 5),
#   ('cannes', 4),
#   ('bens', 3),
#   ('ending', 3),
#   ('beard', 3),
#   ('willis', 3),
#   ('later', 3),
#   ('fiercely', 3),
#   ('killing', 2),
#   ('dog', 2),
#   ('having', 2),
#   ('sean', 2),
#   ('penn', 2),
#   ('problems', 2),
#   ('dogs', 2),
#   ('make', 2),
#   ('scott', 2),
#   ('does', 2),
#   ('movie', 2),
#   ('dor', 2),
#   ('removed', 2),
#   ('wife', 2),
#   ('studio', 2),
#   ('reason', 2),
#   ('palme', 2),
#   ('eventually', 2),
#   ('shave', 2)],
#  'The Tale of Despereaux (film)': [('despereaux', 16),
#   ('roscuro', 13),
#   ('princess', 8),
#   ('soup', 8),
#   ('pea', 7),
#   ('boldo', 6),
#   ('rats', 6),
#   ('world', 5),
#   ('rat', 5),
#   ('tries', 5),
#   ('dungeons', 5),
#   ('castle', 4),
#   ('andre', 4),
#   ('mig', 4),
#   ('peas', 4),
#   ('kingdom', 4),
#   ('mouse', 4),
#   ('trapped', 3),
#   ('botticelli', 3),
#   ('help', 3),
#   ('mice', 3),
#   ('like', 3),
#   ('reading', 3),
#   ('king', 3),
#   ('away', 3),
#   ('makes', 3),
#   ('day', 3),
#   ('council', 2),
#   ('slips', 2),
#   ('eat', 2)],
#  'The Lovely Bones (film)': [('susie', 17),
#   ('harvey', 14),
#   ('susies', 8),
#   ('jack', 7),
#   ('heaven', 5),
#   ('home', 5),
#   ('murdered', 4),
#   ('lindsey', 4),
#   ('harveys', 4),
#   ('safe', 4),
#   ('ray', 3),
#   ('returns', 3),
#   ('mother', 3),
#   ('body', 3),
#   ('afterlife', 3),
#   ('abigail', 3),
#   ('underground', 3),
#   ('ruth', 3),
#   ('urging', 2),
#   ('ruths', 2),
#   ('resists', 2),
#   ('salmon', 2),
#   ('sees', 2),
#   ('police', 2),
#   ('den', 2),
#   ('sinkhole', 2),
#   ('hollys', 2),
#   ('rushes', 2),
#   ('house', 2),
#   ('fenerman', 2)],
#  'Easy A': [('olive', 17),
#   ('school', 5),
#   ('rhiannon', 5),
#   ('griffith', 5),
#   ('mrs', 4),
#   ('todd', 4),
#   ('pretend', 3),
#   ('truth', 3),
#   ('girl', 2),
#   ('boy', 2),
#   ('schools', 2),
#   ('marianne', 2),
#   ('date', 2),
#   ('micah', 2),
#   ('sex', 2),
#   ('believe', 2),
#   ('mr', 2),
#   ('mower', 2),
#   ('comes', 2),
#   ('does', 2),
#   ('virginity', 2),
#   ('telling', 2),
#   ('decides', 2),
#   ('asks', 2),
#   ('outside', 2),
#   ('clothing', 2),
#   ('brandon', 2),
#   ('lies', 2),
#   ('lied', 2),
#   ('lie', 2)],
#  'Burlesque (2010 American film)': [('ali', 23),
#   ('jack', 13),
#   ('tess', 12),
#   ('nikki', 10),
#   ('club', 8),
#   ('marcus', 7),
#   ('sean', 6),
#   ('clubs', 5),
#   ('night', 5),
#   ('drunk', 4),
#   ('tells', 4),
#   ('begins', 4),
#   ('dancers', 4),
#   ('engagement', 3),
#   ('natalie', 3),
#   ('finds', 3),
#   ('makes', 3),
#   ('pay', 3),
#   ('new', 3),
#   ('stage', 3),
#   ('burlesque', 3),
#   ('audition', 3),
#   ('music', 3),
#   ('unable', 2),
#   ('refers', 2),
#   ('making', 2),
#   ('guy', 2),
#   ('replace', 2),
#   ('air', 2),
#   ('nikkis', 2)],
#  'Margin Call': [('firm', 11),
#   ('rogers', 10),
#   ('tuld', 10),
#   ('dale', 7),
#   ('emerson', 6),
#   ('sullivan', 5),
#   ('robertson', 5),
#   ('risk', 5),
#   ('firms', 5),
#   ('crisis', 5),
#   ('assets', 4),
#   ('severance', 4),
#   ('markets', 4),
#   ('securities', 4),
#   ('head', 4),
#   ('toxic', 4),
#   ('plan', 4),
#   ('cohen', 4),
#   ('current', 3),
#   ('music', 3),
#   ('floor', 3),
#   ('office', 3),
#   ('selling', 3),
#   ('night', 3),
#   ('middle', 2),
#   ('seth', 2),
#   ('project', 2),
#   ('warns', 2),
#   ('longer', 2),
#   ('quickly', 2)],
#  'Captain America: The First Avenger': [('rogers', 25),
#   ('schmidt', 7),
#   ('barnes', 7),
#   ('erskine', 6),
#   ('tesseract', 5),
#   ('carter', 4),
#   ('hydra', 4),
#   ('zola', 4),
#   ('aircraft', 3),
#   ('supersoldier', 3),
#   ('war', 3),
#   ('stark', 3),
#   ('schmidts', 3),
#   ('kruger', 3),
#   ('arctic', 2),
#   ('train', 2),
#   ('dum', 2),
#   ('nazi', 2),
#   ('james', 2),
#   ('plane', 2),
#   ('nearly', 2),
#   ('various', 2),
#   ('ocean', 2),
#   ('world', 2),
#   ('scientists', 2),
#   ('red', 2),
#   ('attack', 2),
#   ('shield', 2),
#   ('treatment', 2),
#   ('phillips', 2)],
#  'The Hunger Games (film)': [('katniss', 22),
#   ('peeta', 13),
#   ('district', 8),
#   ('games', 6),
#   ('careers', 6),
#   ('rue', 6),
#   ('crane', 5),
#   ('tribute', 4),
#   ('death', 4),
#   ('haymitch', 3),
#   ('berries', 3),
#   ('kills', 3),
#   ('cato', 3),
#   ('clove', 3),
#   ('nightlock', 3),
#   ('snow', 2),
#   ('change', 2),
#   ('nest', 2),
#   ('cornucopia', 2),
#   ('survivor', 2),
#   ('later', 2),
#   ('shoot', 2),
#   ('thresh', 2),
#   ('kill', 2),
#   ('warns', 2),
#   ('supplies', 2),
#   ('districts', 2),
#   ('hunger', 2),
#   ('announcement', 2),
#   ('modified', 2)],
#  'Gambit (2012 film)': [('harry', 23),
#   ('shabandar', 15),
#   ('pj', 13),
#   ('painting', 10),
#   ('zaidenweber', 5),
#   ('major', 5),
#   ('real', 4),
#   ('art', 4),
#   ('monet', 4),
#   ('tells', 4),
#   ('haystacks', 4),
#   ('dawn', 4),
#   ('takagawa', 4),
#   ('queen', 3),
#   ('agrees', 3),
#   ('shabandars', 2),
#   ('announces', 2),
#   ('texas', 2),
#   ('hotel', 2),
#   ('pjs', 2),
#   ('tries', 2),
#   ('curator', 2),
#   ('picture', 2),
#   ('rodeo', 2),
#   ('meet', 2),
#   ('fake', 2),
#   ('mobile', 2),
#   ('way', 2),
#   ('meets', 2),
#   ('revenge', 2)],
#  'The Company You Keep (film)': [('jim', 26),
#   ('ben', 16),
#   ('mimi', 15),
#   ('daughter', 7),
#   ('isabel', 6),
#   ('rebecca', 5),
#   ('osborne', 5),
#   ('fbi', 5),
#   ('robbery', 5),
#   ('old', 5),
#   ('weather', 4),
#   ('information', 4),
#   ('michigan', 4),
#   ('daniel', 3),
#   ('jed', 3),
#   ('canada', 3),
#   ('years', 3),
#   ('nick', 3),
#   ('cabin', 3),
#   ('learns', 3),
#   ('billy', 3),
#   ('actions', 3),
#   ('reveals', 3),
#   ('sharon', 3),
#   ('hotel', 3),
#   ('solarz', 3),
#   ('underground', 3),
#   ('jims', 3),
#   ('bank', 3),
#   ('young', 3)],
#  'Jack the Giant Slayer': [('jack', 18),
#   ('isabelle', 14),
#   ('elmont', 13),
#   ('giants', 12),
#   ('roderick', 12),
#   ('beanstalk', 9),
#   ('crown', 6),
#   ('takes', 5),
#   ('beans', 5),
#   ('giant', 5),
#   ('castle', 4),
#   ('crawe', 4),
#   ('fallon', 4),
#   ('wicke', 4),
#   ('rodericks', 3),
#   ('jacks', 3),
#   ('brahmwell', 3),
#   ('group', 3),
#   ('cut', 3),
#   ('king', 2),
#   ('eat', 2),
#   ('magic', 2),
#   ('monk', 2),
#   ('attack', 2),
#   ('falls', 2),
#   ('magical', 2),
#   ('fall', 2),
#   ('kingdom', 2),
#   ('marry', 2),
#   ('knights', 2)],
#  'Percy Jackson: Sea of Monsters': [('percy', 16),
#   ('luke', 13),
#   ('fleece', 11),
#   ('grover', 9),
#   ('annabeth', 9),
#   ('clarisse', 7),
#   ('halfblood', 6),
#   ('camp', 6),
#   ('kronos', 6),
#   ('prophecy', 6),
#   ('thalia', 5),
#   ('tyson', 5),
#   ('tree', 4),
#   ('group', 4),
#   ('quest', 4),
#   ('sarcophagus', 4),
#   ('percys', 3),
#   ('bolt', 3),
#   ('monsters', 3),
#   ('thalias', 3),
#   ('escape', 3),
#   ('olympus', 3),
#   ('tells', 2),
#   ('son', 2),
#   ('gods', 2),
#   ('lair', 2),
#   ('revealed', 2),
#   ('polyphemus', 2),
#   ('power', 2),
#   ('human', 2)],
#  'The Fifth Estate (film)': [('assange', 23),
#   ('daniel', 20),
#   ('wikileaks', 10),
#   ('documents', 7),
#   ('sources', 5),
#   ('assanges', 5),
#   ('daniels', 4),
#   ('later', 4),
#   ('world', 3),
#   ('film', 3),
#   ('claims', 3),
#   ('newspapers', 3),
#   ('tells', 3),
#   ('information', 3),
#   ('leak', 3),
#   ('manning', 3),
#   ('website', 3),
#   ('membership', 2),
#   ('site', 2),
#   ('childhood', 2),
#   ('leaks', 2),
#   ('logs', 2),
#   ('including', 2),
#   ('people', 2),
#   ('fear', 2),
#   ('come', 2),
#   ('based', 2),
#   ('injunction', 2),
#   ('cult', 2),
#   ('email', 2)],
#  'The Hunger Games: Catching Fire': [('katniss', 19),
#   ('peeta', 10),
#   ('district', 9),
#   ('games', 8),
#   ('finnick', 7),
#   ('tributes', 5),
#   ('haymitch', 5),
#   ('arena', 4),
#   ('johanna', 4),
#   ('tour', 3),
#   ('snow', 3),
#   ('hunger', 3),
#   ('victors', 3),
#   ('wire', 3),
#   ('beetee', 3),
#   ('gale', 3),
#   ('forced', 3),
#   ('victory', 3),
#   ('unconscious', 3),
#   ('group', 3),
#   ('unable', 2),
#   ('return', 2),
#   ('actions', 2),
#   ('lightning', 2),
#   ('quell', 2),
#   ('clock', 2),
#   ('roof', 2),
#   ('head', 2),
#   ('gloss', 2),
#   ('capitol', 2)],
#  'Some Velvet Morning (film)': [('fred', 10),
#   ('velvet', 8),
#   ('play', 3),
#   ('hell', 2),
#   ('velvets', 2),
#   ('leads', 2),
#   ('escort', 2),
#   ('claiming', 2),
#   ('appointment', 2),
#   ('freds', 2),
#   ('comes', 2),
#   ('time', 1),
#   ('regular', 1),
#   ('walking', 1),
#   ('named', 1),
#   ('forces', 1),
#   ('rowhouse', 1),
#   ('wish', 1),
#   ('met', 1),
#   ('rapes', 1),
#   ('nurse', 1),
#   ('suggests', 1),
#   ('regularly', 1),
#   ('expresses', 1),
#   ('relationship', 1),
#   ('lovers', 1),
#   ('finally', 1),
#   ('returns', 1),
#   ('hour', 1),
#   ('rekindle', 1)],
#  'The Wind Rises': [('jiro', 19),
#   ('naoko', 7),
#   ('aircraft', 6),
#   ('caproni', 5),
#   ('naokos', 5),
#   ('tells', 4),
#   ('castorp', 4),
#   ('junkers', 3),
#   ('mitsubishi', 3),
#   ('summer', 3),
#   ('imperial', 3),
#   ('marry', 3),
#   ('war', 3),
#   ('plane', 3),
#   ('dreams', 3),
#   ('japanese', 2),
#   ('better', 2),
#   ('design', 2),
#   ('jiros', 2),
#   ('family', 2),
#   ('building', 2),
#   ('new', 2),
#   ('leaving', 2),
#   ('designer', 2),
#   ('fighter', 2),
#   ('tuberculosis', 2),
#   ('falcon', 2),
#   ('world', 2),
#   ('life', 2),
#   ('resort', 2)],
#  'Mr. Peabody & Sherman': [('peabody', 23),
#   ('sherman', 20),
#   ('penny', 15),
#   ('grunion', 11),
#   ('shermans', 8),
#   ('wabac', 7),
#   ('dog', 7),
#   ('peabodys', 5),
#   ('figures', 4),
#   ('da', 4),
#   ('time', 4),
#   ('new', 4),
#   ('historical', 4),
#   ('trojan', 4),
#   ('history', 3),
#   ('present', 3),
#   ('away', 3),
#   ('york', 3),
#   ('vinci', 3),
#   ('washington', 3),
#   ('tut', 3),
#   ('ms', 3),
#   ('horse', 3),
#   ('rip', 3),
#   ('agamemnon', 3),
#   ('arrives', 3),
#   ('calls', 3),
#   ('army', 2),
#   ('school', 2),
#   ('mr', 2)],
#  'Muppets Most Wanted': [('constantine', 18),
#   ('dominic', 15),
#   ('kermit', 13),
#   ('muppets', 12),
#   ('piggy', 8),
#   ('miss', 7),
#   ('gulag', 6),
#   ('walter', 5),
#   ('fozzie', 4),
#   ('performance', 4),
#   ('tour', 4),
#   ('napoleon', 4),
#   ('escape', 4),
#   ('sam', 4),
#   ('animal', 3),
#   ('constantines', 3),
#   ('kermits', 3),
#   ('siberian', 3),
#   ('nadya', 3),
#   ('steal', 3),
#   ('london', 3),
#   ('pair', 3),
#   ('piggys', 2),
#   ('wedding', 2),
#   ('agent', 2),
#   ('bomb', 2),
#   ('actually', 2),
#   ('perform', 2),
#   ('lemur', 2),
#   ('museum', 2)],
#  'Transformers: Age of Extinction': [('optimus', 18),
#   ('autobots', 11),
#   ('lockdown', 10),
#   ('cade', 9),
#   ('galvatron', 8),
#   ('seed', 7),
#   ('joshua', 7),
#   ('tessa', 5),
#   ('attinger', 5),
#   ('shane', 4),
#   ('chicago', 3),
#   ('dinobots', 3),
#   ('cemetery', 3),
#   ('creators', 3),
#   ('capture', 3),
#   ('called', 3),
#   ('transformers', 3),
#   ('lucas', 3),
#   ('drones', 3),
#   ('ksi', 3),
#   ('use', 3),
#   ('using', 3),
#   ('megatron', 3),
#   ('wind', 3),
#   ('transformium', 3),
#   ('earth', 2),
#   ('soon', 2),
#   ('large', 2),
#   ('fact', 2),
#   ('hong', 2)],
#  'Wild Card (2015 film)': [('nick', 23),
#   ('demarco', 13),
#   ('holly', 7),
#   ('cyrus', 6),
#   ('men', 6),
#   ('vegas', 5),
#   ('room', 4),
#   ('las', 4),
#   ('baby', 4),
#   ('hotel', 3),
#   ('diner', 3),
#   ('gambling', 3),
#   ('goes', 3),
#   ('takes', 3),
#   ('check', 2),
#   ('decides', 2),
#   ('wants', 2),
#   ('thugs', 2),
#   ('addiction', 2),
#   ('tells', 2),
#   ('dealer', 2),
#   ('accepts', 2),
#   ('demarcos', 2),
#   ('killed', 2),
#   ('woman', 2),
#   ('ticket', 2),
#   ('cassandra', 2),
#   ('friend', 2),
#   ('man', 2),
#   ('blackjack', 2)],
#  'A Little Chaos': [('sabine', 22),
#   ('andré', 11),
#   ('king', 9),
#   ('court', 8),
#   ('daughter', 6),
#   ('garden', 6),
#   ('work', 5),
#   ('kings', 4),
#   ('carriage', 4),
#   ('sabines', 4),
#   ('site', 4),
#   ('finds', 4),
#   ('wife', 4),
#   ('françoise', 4),
#   ('project', 4),
#   ('water', 4),
#   ('design', 3),
#   ('home', 3),
#   ('day', 3),
#   ('fountains', 3),
#   ('versailles', 3),
#   ('designs', 2),
#   ('storm', 2),
#   ('ballroom', 2),
#   ('night', 2),
#   ('gardeners', 2),
#   ('trip', 2),
#   ('mistress', 2),
#   ('nôtre', 2),
#   ('glove', 2)],
#  'The Hunger Games: Mockingjay – Part 1': [('district', 12),
#   ('katniss', 12),
#   ('peeta', 8),
#   ('capitol', 8),
#   ('rebellion', 5),
#   ('snow', 4),
#   ('coin', 4),
#   ('team', 4),
#   ('attack', 4),
#   ('beetee', 3),
#   ('seeing', 3),
#   ('capitols', 3),
#   ('president', 2),
#   ('orders', 2),
#   ('districts', 2),
#   ('singing', 2),
#   ('remaining', 2),
#   ('victors', 2),
#   ('filmed', 2),
#   ('killing', 2),
#   ('gale', 2),
#   ('finnick', 2),
#   ('burn', 2),
#   ('white', 2),
#   ('hospital', 2),
#   ('roses', 2),
#   ('games', 2),
#   ('unexpectedly', 1),
#   ('wave', 1),
#   ('deep', 1)],
#  'Larry Gaye: Renegade Male Flight Attendant': [('flight', 4),
#   ('film', 4),
#   ('attendant', 3),
#   ('renegade', 2),
#   ('larry', 2),
#   ('male', 2),
#   ('pictures', 2),
#   ('gaye', 2),
#   ('warburton', 1),
#   ('metrogoldwynmayer', 1),
#   ('release', 1),
#   ('friedlander', 1),
#   ('concerns', 1),
#   ('distribution', 1),
#   ('obtained', 1),
#   ('rebecca', 1),
#   ('limited', 1),
#   ('mark', 1),
#   ('day', 1),
#   ('sikowitz', 1),
#   ('attendants', 1),
#   ('video', 1),
#   ('human', 1),
#   ('mays', 1),
#   ('mike', 1),
#   ('friedlanders', 1),
#   ('pudi', 1),
#   ('public', 1),
#   ('night', 1),
#   ('robots', 1)],
#  'Spotlight (film)': [('team', 11),
#   ('priests', 9),
#   ('story', 6),
#   ('spotlight', 6),
#   ('rezendes', 5),
#   ('abuse', 5),
#   ('boston', 5),
#   ('victims', 5),
#   ('cardinal', 4),
#   ('robinson', 4),
#   ('garabedian', 4),
#   ('baron', 3),
#   ('list', 3),
#   ('law', 3),
#   ('globe', 3),
#   ('children', 3),
#   ('priest', 3),
#   ('learns', 3),
#   ('documents', 3),
#   ('pedophile', 3),
#   ('policemen', 2),
#   ('lawyer', 2),
#   ('sexual', 2),
#   ('print', 2),
#   ('research', 2),
#   ('begin', 2),
#   ('begins', 2),
#   ('reporter', 2),
#   ('newspapers', 2),
#   ('editor', 2)],
#  'The Hunger Games: Mockingjay – Part 2': [('katniss', 17),
#   ('capitol', 8),
#   ('peeta', 7),
#   ('squad', 6),
#   ('gale', 6),
#   ('games', 5),
#   ('rebels', 4),
#   ('way', 4),
#   ('kill', 4),
#   ('snow', 4),
#   ('coin', 4),
#   ('prim', 3),
#   ('president', 3),
#   ('snows', 3),
#   ('hunger', 3),
#   ('star', 3),
#   ('citizens', 3),
#   ('children', 3),
#   ('boggs', 3),
#   ('fully', 2),
#   ('haymitch', 2),
#   ('district', 2),
#   ('play', 2),
#   ('peacekeepers', 2),
#   ('holo', 2),
#   ('refuses', 2),
#   ('conditioning', 2),
#   ('killing', 2),
#   ('mansion', 2),
#   ('calls', 2)],
#  'Final Portrait': [('lord', 3),
#   ('days', 2),
#   ('genius', 2),
#   ('complies', 1),
#   ('american', 1),
#   ('turn', 1),
#   ('studio', 1),
#   ('finally', 1),
#   ('friend', 1),
#   ('wasted', 1),
#   ('request', 1),
#   ('portrait', 1),
#   ('entire', 1),
#   ('masterpieces', 1),
#   ('frustration', 1),
#   ('realizes', 1),
#   ('model', 1),
#   ('erratic', 1),
#   ('artistic', 1),
#   ('complete', 1),
#   ('weeks', 1),
#   ('vision', 1),
#   ('couple', 1),
#   ('jumping', 1),
#   ('alberto', 1),
#   ('flattered', 1),
#   ('paris', 1),
#   ('old', 1),
#   ('bumps', 1),
#   ('sculptor', 1)],
#  'Beauty and the Beast (2017 film)': [('belle', 20),
#   ('beast', 19),
#   ('maurice', 9),
#   ('gaston', 9),
#   ('castle', 7),
#   ('servants', 6),
#   ('rose', 5),
#   ('father', 5),
#   ('villagers', 4),
#   ('enchantress', 4),
#   ('return', 3),
#   ('fathers', 3),
#   ('villeneuve', 3),
#   ('spell', 3),
#   ('town', 3),
#   ('mirror', 3),
#   ('prince', 3),
#   ('reveals', 3),
#   ('wolves', 2),
#   ('memories', 2),
#   ('finds', 2),
#   ('agrees', 2),
#   ('asylum', 2),
#   ('ball', 2),
#   ('townsfolk', 2),
#   ('magic', 2),
#   ('love', 2),
#   ('dance', 2),
#   ('loved', 2),
#   ('gift', 2)],
#  'Transformers: The Last Knight': [('trf', 13),
#   ('cade', 13),
#   ('staff', 11),
#   ('bumblebee', 9),
#   ('viviane', 7),
#   ('transformers', 7),
#   ('earth', 7),
#   ('knights', 6),
#   ('optimus', 6),
#   ('autobots', 5),
#   ('decepticons', 4),
#   ('transformer', 4),
#   ('burton', 4),
#   ('lennox', 4),
#   ('help', 4),
#   ('merlins', 4),
#   ('battle', 4),
#   ('group', 4),
#   ('izabella', 4),
#   ('talisman', 4),
#   ('nemesis', 4),
#   ('cybertron', 4),
#   ('prime', 3),
#   ('sqweeks', 3),
#   ('cogman', 3),
#   ('stonehenge', 3),
#   ('merlin', 3),
#   ('quintessa', 3),
#   ('spacecraft', 3),
#   ('hidden', 3)],
#  'The Children Act (film)': [('fiona', 15),
#   ('adam', 12),
#   ('transfusion', 5),
#   ('blood', 4),
#   ('returns', 4),
#   ('adams', 3),
#   ('jack', 3),
#   ('saying', 3),
#   ('wants', 3),
#   ('parents', 3),
#   ('court', 2),
#   ('london', 2),
#   ('play', 2),
#   ('follows', 2),
#   ('boy', 2),
#   ('tells', 2),
#   ('sings', 2),
#   ('having', 2),
#   ('salley', 2),
#   ('affair', 2),
#   ('gardens', 2),
#   ('work', 2),
#   ('stop', 2),
#   ('hospital', 2),
#   ('leaves', 2),
#   ('attends', 1),
#   ('encore', 1),
#   ('various', 1),
#   ('away', 1),
#   ('attempting', 1)],
#  'Submission (2017 film)': [('ted', 11),
#   ('angela', 10),
#   ('novel', 8),
#   ('agent', 5),
#   ('students', 4),
#   ('later', 4),
#   ('sex', 4),
#   ('day', 4),
#   ('writing', 4),
#   ('reading', 3),
#   ('tells', 3),
#   ('teacher', 3),
#   ('gets', 3),
#   ('asks', 3),
#   ('comes', 2),
#   ('harassment', 2),
#   ('soon', 2),
#   ('room', 2),
#   ('weak', 2),
#   ('erotic', 2),
#   ('relationship', 2),
#   ('new', 2),
#   ('class', 2),
#   ('science', 2),
#   ('job', 2),
#   ('actually', 2),
#   ('poetry', 2),
#   ('phone', 2),
#   ('shows', 2),
#   ('worker', 2)],
#  'Show Dogs': [('dog', 3),
#   ('smuggling', 2),
#   ('max', 2),
#   ('animal', 2),
#   ('ring', 2),
#   ('fbi', 1),
#   ('macho', 1),
#   ('escape', 1),
#   ('attempts', 1),
#   ('named', 1),
#   ('enemies', 1),
#   ('pose', 1),
#   ('las', 1),
#   ('sold', 1),
#   ('criminals', 1),
#   ('inadvertently', 1),
#   ('involving', 1),
#   ('milbourn', 1),
#   ('letting', 1),
#   ('invitational', 1),
#   ('frank', 1),
#   ('ludacris', 1),
#   ('giant', 1),
#   ('panda', 1),
#   ('rottweiler', 1),
#   ('work', 1),
#   ('stop', 1),
#   ('chris', 1),
#   ('baby', 1),
#   ('blames', 1)],
#  'Patient Zero (film)': [('morgan', 18),
#   ('infected', 13),
#   ('gina', 10),
#   ('janet', 8),
#   ('patient', 6),
#   ('knox', 5),
#   ('humans', 4),
#   ('base', 4),
#   ('zero', 4),
#   ('professor', 4),
#   ('tells', 3),
#   ('human', 3),
#   ('time', 3),
#   ('save', 3),
#   ('goes', 2),
#   ('inside', 2),
#   ('underground', 2),
#   ('finds', 2),
#   ('shoots', 2),
#   ('attacked', 2),
#   ('soldiers', 2),
#   ('lab', 2),
#   ('named', 2),
#   ('wife', 2),
#   ('bitten', 2),
#   ('gun', 2),
#   ('killing', 2),
#   ('long', 2),
#   ('wanted', 2),
#   ('make', 2)],
#  'A Private War': [('colvin', 10),
#   ('marie', 4),
#   ('conroy', 4),
#   ('paul', 4),
#   ('killed', 3),
#   ('ochlik', 3),
#   ('homs', 3),
#   ('cover', 2),
#   ('decides', 2),
#   ('photographer', 2),
#   ('going', 2),
#   ('explosions', 2),
#   ('injured', 2),
#   ('syrian', 2),
#   ('city', 2),
#   ('youre', 2),
#   ('journalist', 2),
#   ('despite', 2),
#   ('movie', 2),
#   ('ryan', 2),
#   ('february', 2),
#   ('attempt', 1),
#   ('american', 1),
#   ('gravely', 1),
#   ('relationship', 1),
#   ('story', 1),
#   ('caught', 1),
#   ('crew', 1),
#   ('reads', 1),
#   ('wakes', 1)],
#  'Night Hunter (2018 film)': [('simon', 9),
#   ('marshall', 7),
#   ('rachel', 6),
#   ('police', 6),
#   ('disabled', 5),
#   ('lara', 5),
#   ('mentally', 4),
#   ('cooper', 4),
#   ('brother', 3),
#   ('twins', 3),
#   ('killed', 2),
#   ('responsible', 2),
#   ('twin', 2),
#   ('young', 2),
#   ('man', 2),
#   ('technician', 2),
#   ('tracker', 2),
#   ('daughter', 2),
#   ('finds', 2),
#   ('forced', 1),
#   ('believing', 1),
#   ('ice', 1),
#   ('takes', 1),
#   ('michael', 1),
#   ('investigating', 1),
#   ('child', 1),
#   ('malevolent', 1),
#   ('lake', 1),
#   ('coopers', 1),
#   ('pair', 1)],
#  'Worth (film)': [('film', 2),
#   ('sundance', 1),
#   ('ramanathan', 1),
#   ('sara', 1),
#   ('tucci', 1),
#   ('premiere', 1),
#   ('worth', 1),
#   ('balsam', 1),
#   ('colangelo', 1),
#   ('shunori', 1),
#   ('world', 1),
#   ('michael', 1),
#   ('stanley', 1),
#   ('stars', 1),
#   ('benantiit', 1),
#   ('talia', 1),
#   ('screenplay', 1),
#   ('laura', 1),
#   ('donovan', 1),
#   ('tate', 1),
#   ('january', 1),
#   ('biographical', 1),
#   ('borenstein', 1),
#   ('directed', 1),
#   ('festival', 1),
#   ('max', 1),
#   ('keaton', 1),
#   ('ryan', 1),
#   ('amy', 1),
#   ('fantasies', 0)],
#  'Supernova (2020 film)': [('kaela', 10),
#   ('karl', 8),
#   ('nick', 7),
#   ('jump', 6),
#   ('ship', 5),
#   ('artifact', 5),
#   ('computer', 5),
#   ('rescue', 4),
#   ('pod', 4),
#   ('dimensional', 4),
#   ('crew', 4),
#   ('medical', 4),
#   ('ships', 4),
#   ('ninedimensional', 4),
#   ('blue', 4),
#   ('titan', 3),
#   ('earth', 3),
#   ('result', 3),
#   ('mining', 3),
#   ('giant', 3),
#   ('matter', 2),
#   ('hours', 2),
#   ('captain', 2),
#   ('supernova', 2),
#   ('technician', 2),
#   ('nightingale', 2),
#   ('left', 2),
#   ('reaction', 2),
#   ('platform', 2),
#   ('eye', 2)],
#  "The King's Man": [('film', 5),
#   ('matthew', 2),
#   ('series', 2),
#   ('kingsman', 2),
#   ('kings', 2),
#   ('man', 2),
#   ('comic', 1),
#   ('comics', 1),
#   ('based', 1),
#   ('wrote', 1),
#   ('prequel', 1),
#   ('mark', 1),
#   ('tom', 1),
#   ('hounsou', 1),
#   ('created', 1),
#   ('daniel', 1),
#   ('djimon', 1),
#   ('spy', 1),
#   ('book', 1),
#   ('marvels', 1),
#   ('gemma', 1),
#   ('goode', 1),
#   ('ifans', 1),
#   ('date', 1),
#   ('comedy', 1),
#   ('september', 1),
#   ('harris', 1),
#   ('cast', 1),
#   ('period', 1),
#   ('studios', 1)],
#  'Jolt (film)': [('cannavale', 1),
#   ('kate', 1),
#   ('tucci', 1),
#   ('wascha', 1),
#   ('action', 1),
#   ('jolt', 1),
#   ('stanley', 1),
#   ('stars', 1),
#   ('upcoming', 1),
#   ('wexler', 1),
#   ('scott', 1),
#   ('screenplay', 1),
#   ('laverne', 1),
#   ('jai', 1),
#   ('courtney', 1),
#   ('tanya', 1),
#   ('beckinsale', 1),
#   ('bobby', 1),
#   ('cox', 1),
#   ('american', 1),
#   ('directed', 1),
#   ('film', 1),
#   ('fiancé', 0),
#   ('fans', 0),
#   ('fame', 0),
#   ('fiercely', 0),
#   ('famed', 0),
#   ('family', 0),
#   ('familyirene', 0),
#   ('familys', 0)],
#  'Moonfall (upcoming film)': [('directed', 1),
#   ('film', 1),
#   ('upcoming', 1),
#   ('roland', 1),
#   ('fiction', 1),
#   ('written', 1),
#   ('science', 1),
#   ('emmerich', 1),
#   ('moonfall', 1),
#   ('fans', 0),
#   ('fascinated', 0),
#   ('fantasizes', 0),
#   ('far', 0),
#   ('farm', 0),
#   ('fancy', 0),
#   ('farthe', 0),
#   ('fancies', 0),
#   ('famously', 0),
#   ('fantasies', 0),
#   ('zoo', 0),
#   ('fascination', 0),
#   ('familys', 0),
#   ('fashion', 0),
#   ('fashionconscious', 0),
#   ('fast', 0),
#   ('fatal', 0),
#   ('fatally', 0),
#   ('fate', 0),
#   ('father', 0),
#   ('fatherat', 0)]}

# %%
from collections import Counter

# Let's first pull out the top 30 words for each comedian
words = []
for movie in data.columns:
    top = [word for (word, count) in top_dict[movie]]
    for t in top:
        words.append(t)
        
words
# Out:
# ['charley',
#  'maerose',
#  'irene',
#  'don',
#  'man',
#  'marksie',
#  'woman',
#  'wife',
#  'charleys',
#  'father',
#  'california',
#  'estranged',
#  'wedding',
#  'york',
#  'casino',
#  'marry',
#  'hit',
#  'family',
#  'fact',
#  'money',
#  'angelo',
#  'ends',
#  'business',
#  'prizzi',
#  'doesnt',
#  'nevada',
#  'eduardo',
#  'acting',
#  'new',
#  'dominic',
#  'nikki',
#  'loudon',
#  'worthington',
#  'mr',
#  'shes',
#  'murray',
#  'bus',
#  'finds',
#  'box',
#  'johnny',
#  'bell',
#  'pick',
#  'love',
#  'woman',
#  'arrested',
#  'wedding',
#  'john',
#  'cougar',
#  'years',
#  'thieves',
#  'men',
#  'theft',
#  'catch',
#  'philadelphia',
#  'vanishes',
#  'intelligent',
#  'new',
#  'plans',
#  'make',
#  'realizes',
#  'ella',
#  'allan',
#  'allans',
#  'melanie',
#  'geoffrey',
#  'house',
#  'romantic',
#  'having',
#  'attempts',
#  'head',
#  'kills',
#  'monkeys',
#  'surgery',
#  'bird',
#  'pentobarbitone',
#  'relationship',
#  'violent',
#  'experimental',
#  'despite',
#  'takes',
#  'condition',
#  'music',
#  'pet',
#  'neck',
#  'wiseman',
#  'summons',
#  'dr',
#  'linda',
#  'tape',
#  'arrives',
#  'eleanor',
#  'stash',
#  'party',
#  'designer',
#  'hat',
#  'fashion',
#  'new',
#  'ride',
#  'jan',
#  'artist',
#  'elaborate',
#  'discovers',
#  'artists',
#  'relationship',
#  'friend',
#  'dangerous',
#  'group',
#  'talk',
#  'sequencewhile',
#  'meets',
#  'crumbling',
#  'morning',
#  'city',
#  'buying',
#  'unfaithful',
#  'indifference',
#  'offers',
#  'boyfriend',
#  'invites',
#  'despite',
#  'girlfriend',
#  'sharon',
#  'iras',
#  'east',
#  'apparent',
#  'manhattan',
#  'ellis',
#  'scene',
#  'work',
#  'actress',
#  'despair',
#  'chubby',
#  'painter',
#  'castoff',
#  'vignettes',
#  'achieved',
#  'performance',
#  'village',
#  'equally',
#  'old',
#  'unsuccessful',
#  'including',
#  'friend',
#  'aspiring',
#  'jack',
#  'donny',
#  'roles',
#  'playwright',
#  'plays',
#  'artist',
#  'chief',
#  'new',
#  'phyllis',
#  'airport',
#  'trio',
#  'driver',
#  'loomis',
#  'cab',
#  'gets',
#  'york',
#  'department',
#  'grimm',
#  'bank',
#  'city',
#  'robbers',
#  'robs',
#  'away',
#  'airliner',
#  'brooklyn',
#  'broken',
#  'simple',
#  'brooklynqueens',
#  'dressed',
#  'news',
#  'newsstand',
#  'taken',
#  'english',
#  'hydrant',
#  'assistance',
#  'flight',
#  'battaglia',
#  'family',
#  'damico',
#  'son',
#  'duffy',
#  'way',
#  'kill',
#  'woman',
#  'hit',
#  'ruthie',
#  'boss',
#  'assume',
#  'wife',
#  'ally',
#  'born',
#  'control',
#  'powerful',
#  'battaglias',
#  'harm',
#  'coronation',
#  'lieutenant',
#  'largescale',
#  'proclaims',
#  'suspects',
#  'desert',
#  'mike',
#  'drunken',
#  'reign',
#  'survives',
#  'spell',
#  'schultz',
#  'billy',
#  'drew',
#  'schultzs',
#  'dutch',
#  'money',
#  'luciano',
#  'gangster',
#  'court',
#  'bribe',
#  'begins',
#  'billys',
#  'beaten',
#  'falling',
#  'charges',
#  'rejected',
#  'federal',
#  'men',
#  'boy',
#  'dutchs',
#  'rap',
#  'lets',
#  'boss',
#  'day',
#  'letting',
#  'wants',
#  'natured',
#  'fired',
#  'warns',
#  'teenage',
#  'soups',
#  'thickened',
#  'clear',
#  'include',
#  'ingredients',
#  'cream',
#  'vegetables',
#  'liquid',
#  'classified',
#  'hot',
#  'french',
#  'cold',
#  'soup',
#  'used',
#  'broth',
#  'generally',
#  'broths',
#  'stock',
#  'puréed',
#  'purées',
#  'boiling',
#  'stewsin',
#  'grains',
#  'butter',
#  'classifications',
#  'rice',
#  'similar',
#  'depending',
#  'pot',
#  'potatoes',
#  'beethoven',
#  'george',
#  'dr',
#  'varnick',
#  'newtons',
#  'euthanized',
#  'dogs',
#  'family',
#  'varnicks',
#  'dog',
#  'vernon',
#  'st',
#  'ted',
#  'home',
#  'ryce',
#  'newton',
#  'emily',
#  'harvey',
#  'alice',
#  'bernards',
#  'tells',
#  'office',
#  'fake',
#  'fears',
#  'captive',
#  'familys',
#  'animal',
#  'takes',
#  'car',
#  'escape',
#  'soul',
#  'rita',
#  'life',
#  'peter',
#  'afraid',
#  'julius',
#  'fears',
#  'wanted',
#  'elderly',
#  'beautiful',
#  'spirits',
#  'convincing',
#  'return',
#  'aspiring',
#  'freespirited',
#  'anymore',
#  'wedding',
#  'old',
#  'chicago',
#  'permission',
#  'house',
#  'love',
#  'residing',
#  'man',
#  'switch',
#  'sees',
#  'designer',
#  'approached',
#  'boyle',
#  'liberal',
#  'kay',
#  'bernzy',
#  'police',
#  'mob',
#  'great',
#  'bernstein',
#  'sal',
#  'place',
#  'races',
#  'nabler',
#  'life',
#  'photographs',
#  'photographer',
#  'rationing',
#  'waits',
#  'dashboard',
#  'quickly',
#  'federal',
#  'local',
#  'darkroom',
#  'interested',
#  'muscling',
#  'vivid',
#  'murdered',
#  'radio',
#  'danger',
#  'war',
#  'death',
#  'involving',
#  'suspect',
#  'novacek',
#  'jane',
#  'jeff',
#  'daughter',
#  'blues',
#  'explosive',
#  'muerte',
#  'leave',
#  'sawyer',
#  'orleans',
#  'new',
#  'helicopter',
#  'novaceks',
#  'mugging',
#  'attempts',
#  'tracker',
#  'frank',
#  'life',
#  'boat',
#  'away',
#  'case',
#  'follows',
#  'louise',
#  'continually',
#  'called',
#  'maternity',
#  'looking',
#  'mug',
#  'rumored',
#  'grasp',
#  'darby',
#  'grantham',
#  'mattiece',
#  'killed',
#  'brief',
#  'justices',
#  'fbi',
#  'gives',
#  'oil',
#  'president',
#  'white',
#  'washington',
#  'court',
#  'darbys',
#  'verheek',
#  'khamel',
#  'contacts',
#  'law',
#  'information',
#  'box',
#  'theory',
#  'meet',
#  'confirms',
#  'unknown',
#  'attacked',
#  'blazevich',
#  'director',
#  'manages',
#  'turn',
#  'accurate',
#  'yvonne',
#  'charlie',
#  'muriel',
#  'diner',
#  'money',
#  'new',
#  'gets',
#  'divorce',
#  'job',
#  'york',
#  'eddie',
#  'man',
#  'day',
#  'doesnt',
#  'lottery',
#  'apartment',
#  'end',
#  'ticket',
#  'million',
#  'force',
#  'tip',
#  'works',
#  'account',
#  'court',
#  'pay',
#  'jack',
#  'gross',
#  'waitress',
#  'husband',
#  'just',
#  'film',
#  'benchley',
#  'critics',
#  'shawn',
#  'algonquin',
#  'leigh',
#  'parker',
#  'crowninshield',
#  'editor',
#  'rudolph',
#  'humorist',
#  'biographical',
#  'won',
#  'official',
#  'washington',
#  'selection',
#  'wallace',
#  'actresspeter',
#  'vicious',
#  'round',
#  'national',
#  'actors',
#  'actor',
#  'critical',
#  'met',
#  'frank',
#  'circle',
#  'palme',
#  'grandson',
#  'manhattans',
#  'film',
#  'love',
#  'directed',
#  'romanticdrama',
#  'cabiria',
#  'fellinis',
#  'competition',
#  'somebody',
#  'festival',
#  'inspired',
#  'nights',
#  'venice',
#  'international',
#  'federico',
#  'rockwell',
#  'american',
#  'entered',
#  'alexandre',
#  'fate',
#  'fault',
#  'faucet',
#  'fancy',
#  'fans',
#  'fantasies',
#  'fantasizes',
#  'fathers',
#  'far',
#  'farm',
#  'fascinated',
#  'farthe',
#  'tommy',
#  'frank',
#  'jurors',
#  'finds',
#  'monica',
#  'evidence',
#  'bishop',
#  'jury',
#  'carl',
#  'fast',
#  'polystyrene',
#  'food',
#  'wayne',
#  'room',
#  'guilty',
#  'suite',
#  'man',
#  'peanut',
#  'later',
#  'decides',
#  'case',
#  'school',
#  'goes',
#  'seeing',
#  'erotic',
#  'staying',
#  'library',
#  'away',
#  'park',
#  'help',
#  'jimmy',
#  'junior',
#  'little',
#  'ronnie',
#  'bev',
#  'cars',
#  'brown',
#  'browns',
#  'jimmys',
#  'death',
#  'ronnies',
#  'rosie',
#  'stolen',
#  'meeting',
#  'daughter',
#  'car',
#  'cakes',
#  'baby',
#  'city',
#  'just',
#  'police',
#  'bevs',
#  'takes',
#  'omar',
#  'goes',
#  'arrest',
#  'returns',
#  'shop',
#  'arrive',
#  'navy',
#  'film',
#  'anton',
#  'stanley',
#  'kari',
#  'conrad',
#  'sankothe',
#  'wuhrer',
#  'known',
#  'tucci',
#  'eldard',
#  'drama',
#  'sex',
#  'starring',
#  'composed',
#  'ron',
#  'man',
#  'roles',
#  'comedy',
#  'slovin',
#  'lead',
#  'karl',
#  'goode',
#  'music',
#  'directed',
#  'american',
#  'captive',
#  'festival',
#  'fantasies',
#  'famed',
#  'family',
#  'affair',
#  'modern',
#  'film',
#  'pregnant',
#  'woman',
#  'sperm',
#  'grace',
#  'intimacy',
#  'identity',
#  'going',
#  'man',
#  'world',
#  'commitment',
#  'father',
#  'lisa',
#  'love',
#  'stanley',
#  'baby',
#  'bank',
#  'eichhorn',
#  'feature',
#  'elaine',
#  'tucci',
#  'advice',
#  'goes',
#  'rhodes',
#  'begins',
#  'parenthooda',
#  'rocked',
#  'new',
#  'family',
#  'parents',
#  'husband',
#  'anne',
#  'boyfriend',
#  'sister',
#  'island',
#  'tucci',
#  'rita',
#  'carl',
#  'love',
#  'prove',
#  'affair',
#  'confront',
#  'discovers',
#  'schreiber',
#  'including',
#  'posey',
#  'louis',
#  'new',
#  'davis',
#  'stanley',
#  'parker',
#  'york',
#  'jos',
#  'station',
#  'having',
#  'hope',
#  'mcnamara',
#  'pat',
#  'secondo',
#  'primo',
#  'restaurant',
#  'food',
#  'pascal',
#  'brothers',
#  'prima',
#  'brother',
#  'paradise',
#  'phyllis',
#  'gabriella',
#  'work',
#  'primos',
#  'singer',
#  'singers',
#  'magnificent',
#  'louis',
#  'admits',
#  'hours',
#  'secondos',
#  'return',
#  'dish',
#  'italian',
#  'reporter',
#  'despite',
#  'beach',
#  'called',
#  'offer',
#  'new',
#  'refuses',
#  'harry',
#  'richard',
#  'fay',
#  'harrys',
#  'ceremony',
#  'based',
#  'novel',
#  'lucy',
#  'asks',
#  'story',
#  'hilliard',
#  'cookie',
#  'gun',
#  'university',
#  'universitys',
#  'billy',
#  'larry',
#  'accompany',
#  'writing',
#  'fictional',
#  'character',
#  'latest',
#  'gets',
#  'crystal',
#  'sexobsessed',
#  'man',
#  'husband',
#  'wedding',
#  'begins',
#  'having',
#  'film',
#  'written',
#  'keith',
#  'crime',
#  'known',
#  'tucci',
#  'wartime',
#  'reddin',
#  'starring',
#  'adaptation',
#  'play',
#  'kate',
#  'dunsky',
#  'comedy',
#  'ryan',
#  'alarmist',
#  'david',
#  'reynolds',
#  'arquette',
#  'directed',
#  'life',
#  'evan',
#  'stanley',
#  'capshaw',
#  'fashionconscious',
#  'father',
#  'fantasies',
#  'fantasizes',
#  'fatherinlaw',
#  'fatherat',
#  'celine',
#  'robert',
#  'jackson',
#  'oreilly',
#  'naville',
#  'love',
#  'money',
#  'runs',
#  'mayhew',
#  'gabriel',
#  'bar',
#  'roberts',
#  'case',
#  'knocks',
#  'angels',
#  'drive',
#  'elliott',
#  'shoots',
#  'tells',
#  'woods',
#  'car',
#  'head',
#  'cabin',
#  'poem',
#  'decides',
#  'daughter',
#  'says',
#  'heart',
#  'gun',
#  'file',
#  'etruscan',
#  'old',
#  'daughter',
#  'girls',
#  'building',
#  'man',
#  'prophecy',
#  'scientist',
#  'father',
#  'girl',
#  'dead',
#  'perfect',
#  'just',
#  'america',
#  'experiments',
#  'eighteen',
#  'mysterious',
#  'mother',
#  'turns',
#  'biologically',
#  'artificially',
#  'beings',
#  'rise',
#  'wife',
#  'begins',
#  'secret',
#  'picture',
#  'north',
#  'physically',
#  'sect',
#  'kitty',
#  'claire',
#  'boss',
#  'targeted',
#  'retrieving',
#  'hit',
#  'professional',
#  'kyra',
#  'girlfriend',
#  'gives',
#  'woman',
#  'sedgwick',
#  'stop',
#  'ethan',
#  'robin',
#  'tunney',
#  'embry',
#  'tracks',
#  'coltrane',
#  'incompetent',
#  'level',
#  'low',
#  'son',
#  'runaway',
#  'task',
#  'robbie',
#  'unable',
#  'organization',
#  'killing',
#  'fashion',
#  'burtom',
#  'actor',
#  'tennis',
#  'professional',
#  'drunken',
#  'stowaways',
#  'diverse',
#  'jeremy',
#  'crooner',
#  'hide',
#  'city',
#  'happy',
#  'buscemi',
#  'language',
#  'duo',
#  'ocean',
#  'named',
#  'acting',
#  'billy',
#  'moremistaken',
#  'franks',
#  'bomber',
#  'confrontation',
#  'sobs',
#  'ensue',
#  'swindles',
#  'practicing',
#  'platt',
#  'stanley',
#  'mad',
#  'titania',
#  'oberon',
#  'demetrius',
#  'hermia',
#  'lysander',
#  'helena',
#  'forest',
#  'puck',
#  'tragedy',
#  'queen',
#  'troupe',
#  'young',
#  'duke',
#  'lovers',
#  'fairies',
#  'play',
#  'love',
#  'actors',
#  'desperately',
#  'seen',
#  'bower',
#  'tires',
#  'final',
#  'plan',
#  'wander',
#  'famously',
#  'rehearsal',
#  'athena',
#  'woos',
#  'unintentionally',
#  'cole',
#  'gittens',
#  'undercover',
#  'reid',
#  'dambrosio',
#  'crew',
#  'eventually',
#  'begins',
#  'myra',
#  'breezy',
#  'work',
#  'man',
#  'police',
#  'scott',
#  'superiors',
#  'god',
#  'deep',
#  'starts',
#  'officers',
#  'identity',
#  'unhinged',
#  'coles',
#  'organization',
#  'cop',
#  'members',
#  'drug',
#  'far',
#  'connelly',
#  'empire',
#  'goes',
#  'gould',
#  'mitchell',
#  'village',
#  'joe',
#  'demanding',
#  'opus',
#  'bearded',
#  'portrait',
#  'mans',
#  'colorful',
#  'portfolio',
#  'time',
#  'people',
#  'perceptive',
#  'times',
#  'manhattan',
#  'wanders',
#  'life',
#  'sweet',
#  'daughters',
#  'obnoxious',
#  'greenwich',
#  'hes',
#  'collecting',
#  'support',
#  'merely',
#  'occasional',
#  'founder',
#  'shop',
#  'actually',
#  'eddie',
#  'gwen',
#  'kiki',
#  'lee',
#  'film',
#  'press',
#  'hector',
#  'weidmann',
#  'junket',
#  'time',
#  'gwens',
#  'eddies',
#  'convince',
#  'affair',
#  'love',
#  'tells',
#  'believes',
#  'assistant',
#  'career',
#  'refuses',
#  'stories',
#  'work',
#  'studios',
#  'movie',
#  'public',
#  'portrayed',
#  'weidmanns',
#  'leave',
#  'relationship',
#  'crew',
#  'bridget',
#  'film',
#  'tucci',
#  'retired',
#  'george',
#  'starring',
#  'role',
#  'appeared',
#  'movie',
#  'movies',
#  ...]

# %%
# Let's aggregate this list and identify the most common words along with how many routines they occur in
Counter(words).most_common()
# Out:
# [('film', 18),
#  ('new', 17),
#  ('man', 14),
#  ('tells', 14),
#  ('stanley', 11),
#  ('day', 10),
#  ('father', 9),
#  ('family', 9),
#  ('finds', 9),
#  ('love', 9),
#  ('life', 9),
#  ('tucci', 9),
#  ('time', 9),
#  ('begins', 8),
#  ('directed', 8),
#  ('wife', 7),
#  ('city', 7),
#  ('work', 7),
#  ('home', 7),
#  ('daughter', 7),
#  ('later', 7),
#  ('goes', 7),
#  ('world', 7),
#  ('woman', 6),
#  ('york', 6),
#  ('relationship', 6),
#  ('takes', 6),
#  ('jack', 6),
#  ('gets', 6),
#  ('away', 6),
#  ('escape', 6),
#  ('killed', 6),
#  ('american', 6),
#  ('fantasies', 6),
#  ('play', 6),
#  ('wedding', 5),
#  ('money', 5),
#  ('having', 5),
#  ('head', 5),
#  ('fashion', 5),
#  ('group', 5),
#  ('old', 5),
#  ('son', 5),
#  ('kill', 5),
#  ('court', 5),
#  ('dog', 5),
#  ('return', 5),
#  ('police', 5),
#  ('just', 5),
#  ('festival', 5),
#  ('fantasizes', 5),
#  ('decides', 5),
#  ('returns', 5),
#  ('affair', 5),
#  ('gun', 5),
#  ('killing', 5),
#  ('mr', 4),
#  ('men', 4),
#  ('make', 4),
#  ('despite', 4),
#  ('music', 4),
#  ('friend', 4),
#  ('way', 4),
#  ('boss', 4),
#  ('billy', 4),
#  ('boy', 4),
#  ('wants', 4),
#  ('car', 4),
#  ('frank', 4),
#  ('case', 4),
#  ('called', 4),
#  ('fbi', 4),
#  ('fans', 4),
#  ('farm', 4),
#  ('room', 4),
#  ('school', 4),
#  ('help', 4),
#  ('baby', 4),
#  ('starring', 4),
#  ('comedy', 4),
#  ('identity', 4),
#  ('asks', 4),
#  ('shoots', 4),
#  ('mother', 4),
#  ('unable', 4),
#  ('named', 4),
#  ('young', 4),
#  ('crew', 4),
#  ('movie', 4),
#  ('date', 4),
#  ('hotel', 4),
#  ('nick', 4),
#  ('earth', 4),
#  ('night', 4),
#  ('katniss', 4),
#  ('peeta', 4),
#  ('district', 4),
#  ('games', 4),
#  ('snow', 4),
#  ('marry', 3),
#  ('hit', 3),
#  ('box', 3),
#  ('years', 3),
#  ('house', 3),
#  ('attempts', 3),
#  ('kills', 3),
#  ('dr', 3),
#  ('arrives', 3),
#  ('designer', 3),
#  ('girlfriend', 3),
#  ('including', 3),
#  ('airport', 3),
#  ('bank', 3),
#  ('warns', 3),
#  ('familys', 3),
#  ('animal', 3),
#  ('sees', 3),
#  ('murdered', 3),
#  ('war', 3),
#  ('death', 3),
#  ('leave', 3),
#  ('president', 3),
#  ('washington', 3),
#  ('information', 3),
#  ('meet', 3),
#  ('director', 3),
#  ('job', 3),
#  ('eddie', 3),
#  ('husband', 3),
#  ('editor', 3),
#  ('actors', 3),
#  ('actor', 3),
#  ('fancy', 3),
#  ('fathers', 3),
#  ('far', 3),
#  ('fascinated', 3),
#  ('farthe', 3),
#  ('food', 3),
#  ('shop', 3),
#  ('drama', 3),
#  ('sex', 3),
#  ('famed', 3),
#  ('refuses', 3),
#  ('based', 3),
#  ('novel', 3),
#  ('story', 3),
#  ('larry', 3),
#  ('written', 3),
#  ('ryan', 3),
#  ('stop', 3),
#  ('eventually', 3),
#  ('scott', 3),
#  ('actually', 3),
#  ('couple', 3),
#  ('plane', 3),
#  ('michael', 3),
#  ('shows', 3),
#  ('team', 3),
#  ('makes', 3),
#  ('finally', 3),
#  ('studio', 3),
#  ('miss', 3),
#  ('max', 3),
#  ('does', 3),
#  ('screenplay', 3),
#  ('stars', 3),
#  ('castle', 3),
#  ('king', 3),
#  ('underground', 3),
#  ('comes', 3),
#  ('attack', 3),
#  ('haymitch', 3),
#  ('hunger', 3),
#  ('daniel', 3),
#  ('giant', 3),
#  ('human', 3),
#  ('gale', 3),
#  ('capitol', 3),
#  ('fact', 2),
#  ('ends', 2),
#  ('doesnt', 2),
#  ('acting', 2),
#  ('dominic', 2),
#  ('nikki', 2),
#  ('john', 2),
#  ('realizes', 2),
#  ('romantic', 2),
#  ('party', 2),
#  ('artist', 2),
#  ('discovers', 2),
#  ('meets', 2),
#  ('boyfriend', 2),
#  ('sharon', 2),
#  ('manhattan', 2),
#  ('performance', 2),
#  ('village', 2),
#  ('aspiring', 2),
#  ('roles', 2),
#  ('plays', 2),
#  ('phyllis', 2),
#  ('flight', 2),
#  ('mike', 2),
#  ('drunken', 2),
#  ('spell', 2),
#  ('dutch', 2),
#  ('charges', 2),
#  ('federal', 2),
#  ('letting', 2),
#  ('clear', 2),
#  ('soup', 2),
#  ('used', 2),
#  ('george', 2),
#  ('dogs', 2),
#  ('ted', 2),
#  ('emily', 2),
#  ('harvey', 2),
#  ('office', 2),
#  ('fake', 2),
#  ('fears', 2),
#  ('captive', 2),
#  ('rita', 2),
#  ('peter', 2),
#  ('wanted', 2),
#  ('chicago', 2),
#  ('mob', 2),
#  ('photographer', 2),
#  ('quickly', 2),
#  ('local', 2),
#  ('involving', 2),
#  ('suspect', 2),
#  ('tracker', 2),
#  ('follows', 2),
#  ('gives', 2),
#  ('white', 2),
#  ('law', 2),
#  ('attacked', 2),
#  ('turn', 2),
#  ('diner', 2),
#  ('apartment', 2),
#  ('end', 2),
#  ('ticket', 2),
#  ('pay', 2),
#  ('parker', 2),
#  ('biographical', 2),
#  ('won', 2),
#  ('met', 2),
#  ('palme', 2),
#  ('competition', 2),
#  ('fate', 2),
#  ('monica', 2),
#  ('evidence', 2),
#  ('carl', 2),
#  ('fast', 2),
#  ('peanut', 2),
#  ('seeing', 2),
#  ('erotic', 2),
#  ('known', 2),
#  ('lead', 2),
#  ('karl', 2),
#  ('goode', 2),
#  ('going', 2),
#  ('parents', 2),
#  ('anne', 2),
#  ('island', 2),
#  ('louis', 2),
#  ('brother', 2),
#  ('hours', 2),
#  ('reporter', 2),
#  ('harry', 2),
#  ('richard', 2),
#  ('writing', 2),
#  ('kate', 2),
#  ('david', 2),
#  ('fashionconscious', 2),
#  ('fatherat', 2),
#  ('cabin', 2),
#  ('building', 2),
#  ('prophecy', 2),
#  ('girl', 2),
#  ('picture', 2),
#  ('professional', 2),
#  ('task', 2),
#  ('organization', 2),
#  ('jeremy', 2),
#  ('ocean', 2),
#  ('queen', 2),
#  ('lovers', 2),
#  ('final', 2),
#  ('plan', 2),
#  ('famously', 2),
#  ('deep', 2),
#  ('starts', 2),
#  ('portrait', 2),
#  ('people', 2),
#  ('assistant', 2),
#  ('studios', 2),
#  ('public', 2),
#  ('bomb', 2),
#  ('criminals', 2),
#  ('walter', 2),
#  ('nuclear', 2),
#  ('sullivan', 2),
#  ('chris', 2),
#  ('real', 2),
#  ('staff', 2),
#  ('power', 2),
#  ('field', 2),
#  ('pressure', 2),
#  ('limited', 2),
#  ('cannes', 2),
#  ('gift', 2),
#  ('newspaper', 2),
#  ('longer', 2),
#  ('dance', 2),
#  ('town', 2),
#  ('robots', 2),
#  ('lindsey', 2),
#  ('revealed', 2),
#  ('gambling', 2),
#  ('miranda', 2),
#  ('paris', 2),
#  ('replace', 2),
#  ('leaving', 2),
#  ('truth', 2),
#  ('fenerman', 2),
#  ('fame', 2),
#  ('blue', 2),
#  ('leads', 2),
#  ('late', 2),
#  ('sundance', 2),
#  ('fascination', 2),
#  ('titan', 2),
#  ('ship', 2),
#  ('scientists', 2),
#  ('use', 2),
#  ('major', 2),
#  ('ben', 2),
#  ('fiercely', 2),
#  ('sean', 2),
#  ('tries', 2),
#  ('kingdom', 2),
#  ('reading', 2),
#  ('eat', 2),
#  ('rogers', 2),
#  ('project', 2),
#  ('aircraft', 2),
#  ('various', 2),
#  ('districts', 2),
#  ('agrees', 2),
#  ('rebecca', 2),
#  ('learns', 2),
#  ('actions', 2),
#  ('reveals', 2),
#  ('magic', 2),
#  ('knights', 2),
#  ('documents', 2),
#  ('newspapers', 2),
#  ('site', 2),
#  ('finnick', 2),
#  ('tour', 2),
#  ('victors', 2),
#  ('beetee', 2),
#  ('forced', 2),
#  ('design', 2),
#  ('calls', 2),
#  ('london', 2),
#  ('pair', 2),
#  ('agent', 2),
#  ('optimus', 2),
#  ('autobots', 2),
#  ('cade', 2),
#  ('transformers', 2),
#  ('soon', 2),
#  ('las', 2),
#  ('kings', 2),
#  ('coin', 2),
#  ('hospital', 2),
#  ('mark', 2),
#  ('children', 2),
#  ('science', 2),
#  ('technician', 2),
#  ('upcoming', 2),
#  ('charley', 1),
#  ('maerose', 1),
#  ('irene', 1),
#  ('don', 1),
#  ('marksie', 1),
#  ('charleys', 1),
#  ('california', 1),
#  ('estranged', 1),
#  ('casino', 1),
#  ('angelo', 1),
#  ('business', 1),
#  ('prizzi', 1),
#  ('nevada', 1),
#  ('eduardo', 1),
#  ('loudon', 1),
#  ('worthington', 1),
#  ('shes', 1),
#  ('murray', 1),
#  ('bus', 1),
#  ('johnny', 1),
#  ('bell', 1),
#  ('pick', 1),
#  ('arrested', 1),
#  ('cougar', 1),
#  ('thieves', 1),
#  ('theft', 1),
#  ('catch', 1),
#  ('philadelphia', 1),
#  ('vanishes', 1),
#  ('intelligent', 1),
#  ('plans', 1),
#  ('ella', 1),
#  ('allan', 1),
#  ('allans', 1),
#  ('melanie', 1),
#  ('geoffrey', 1),
#  ('monkeys', 1),
#  ('surgery', 1),
#  ('bird', 1),
#  ('pentobarbitone', 1),
#  ('violent', 1),
#  ('experimental', 1),
#  ('condition', 1),
#  ('pet', 1),
#  ('neck', 1),
#  ('wiseman', 1),
#  ('summons', 1),
#  ('linda', 1),
#  ('tape', 1),
#  ('eleanor', 1),
#  ('stash', 1),
#  ('hat', 1),
#  ('ride', 1),
#  ('jan', 1),
#  ('elaborate', 1),
#  ('artists', 1),
#  ('dangerous', 1),
#  ('talk', 1),
#  ('sequencewhile', 1),
#  ('crumbling', 1),
#  ('morning', 1),
#  ('buying', 1),
#  ('unfaithful', 1),
#  ('indifference', 1),
#  ('offers', 1),
#  ('invites', 1),
#  ('iras', 1),
#  ('east', 1),
#  ('apparent', 1),
#  ('ellis', 1),
#  ('scene', 1),
#  ('actress', 1),
#  ('despair', 1),
#  ('chubby', 1),
#  ('painter', 1),
#  ('castoff', 1),
#  ('vignettes', 1),
#  ('achieved', 1),
#  ('equally', 1),
#  ('unsuccessful', 1),
#  ('donny', 1),
#  ('playwright', 1),
#  ('chief', 1),
#  ('trio', 1),
#  ('driver', 1),
#  ('loomis', 1),
#  ('cab', 1),
#  ('department', 1),
#  ('grimm', 1),
#  ('robbers', 1),
#  ('robs', 1),
#  ('airliner', 1),
#  ('brooklyn', 1),
#  ('broken', 1),
#  ('simple', 1),
#  ('brooklynqueens', 1),
#  ('dressed', 1),
#  ('news', 1),
#  ('newsstand', 1),
#  ('taken', 1),
#  ('english', 1),
#  ('hydrant', 1),
#  ('assistance', 1),
#  ('battaglia', 1),
#  ('damico', 1),
#  ('duffy', 1),
#  ('ruthie', 1),
#  ('assume', 1),
#  ('ally', 1),
#  ('born', 1),
#  ('control', 1),
#  ('powerful', 1),
#  ('battaglias', 1),
#  ('harm', 1),
#  ('coronation', 1),
#  ('lieutenant', 1),
#  ('largescale', 1),
#  ('proclaims', 1),
#  ('suspects', 1),
#  ('desert', 1),
#  ('reign', 1),
#  ('survives', 1),
#  ('schultz', 1),
#  ('drew', 1),
#  ('schultzs', 1),
#  ('luciano', 1),
#  ('gangster', 1),
#  ('bribe', 1),
#  ('billys', 1),
#  ('beaten', 1),
#  ('falling', 1),
#  ('rejected', 1),
#  ('dutchs', 1),
#  ('rap', 1),
#  ('lets', 1),
#  ('natured', 1),
#  ('fired', 1),
#  ('teenage', 1),
#  ('soups', 1),
#  ('thickened', 1),
#  ('include', 1),
#  ('ingredients', 1),
#  ('cream', 1),
#  ('vegetables', 1),
#  ('liquid', 1),
#  ('classified', 1),
#  ('hot', 1),
#  ('french', 1),
#  ('cold', 1),
#  ('broth', 1),
#  ('generally', 1),
#  ('broths', 1),
#  ('stock', 1),
#  ('puréed', 1),
#  ('purées', 1),
#  ('boiling', 1),
#  ('stewsin', 1),
#  ('grains', 1),
#  ('butter', 1),
#  ('classifications', 1),
#  ('rice', 1),
#  ('similar', 1),
#  ('depending', 1),
#  ('pot', 1),
#  ('potatoes', 1),
#  ('beethoven', 1),
#  ('varnick', 1),
#  ('newtons', 1),
#  ('euthanized', 1),
#  ('varnicks', 1),
#  ('vernon', 1),
#  ('st', 1),
#  ('ryce', 1),
#  ('newton', 1),
#  ('alice', 1),
#  ('bernards', 1),
#  ('soul', 1),
#  ('afraid', 1),
#  ('julius', 1),
#  ('elderly', 1),
#  ('beautiful', 1),
#  ('spirits', 1),
#  ('convincing', 1),
#  ('freespirited', 1),
#  ('anymore', 1),
#  ('permission', 1),
#  ('residing', 1),
#  ('switch', 1),
#  ('approached', 1),
#  ('boyle', 1),
#  ('liberal', 1),
#  ('kay', 1),
#  ('bernzy', 1),
#  ('great', 1),
#  ('bernstein', 1),
#  ('sal', 1),
#  ('place', 1),
#  ('races', 1),
#  ('nabler', 1),
#  ('photographs', 1),
#  ('rationing', 1),
#  ('waits', 1),
#  ('dashboard', 1),
#  ('darkroom', 1),
#  ('interested', 1),
#  ('muscling', 1),
#  ('vivid', 1),
#  ('radio', 1),
#  ('danger', 1),
#  ('novacek', 1),
#  ('jane', 1),
#  ('jeff', 1),
#  ('blues', 1),
#  ('explosive', 1),
#  ('muerte', 1),
#  ('sawyer', 1),
#  ('orleans', 1),
#  ('helicopter', 1),
#  ('novaceks', 1),
#  ('mugging', 1),
#  ('boat', 1),
#  ('louise', 1),
#  ('continually', 1),
#  ('maternity', 1),
#  ('looking', 1),
#  ('mug', 1),
#  ('rumored', 1),
#  ('grasp', 1),
#  ('darby', 1),
#  ('grantham', 1),
#  ('mattiece', 1),
#  ('brief', 1),
#  ('justices', 1),
#  ('oil', 1),
#  ('darbys', 1),
#  ('verheek', 1),
#  ('khamel', 1),
#  ('contacts', 1),
#  ('theory', 1),
#  ('confirms', 1),
#  ('unknown', 1),
#  ('blazevich', 1),
#  ('manages', 1),
#  ('accurate', 1),
#  ('yvonne', 1),
#  ('charlie', 1),
#  ('muriel', 1),
#  ('divorce', 1),
#  ('lottery', 1),
#  ('million', 1),
#  ('force', 1),
#  ('tip', 1),
#  ('works', 1),
#  ('account', 1),
#  ('gross', 1),
#  ('waitress', 1),
#  ('benchley', 1),
#  ('critics', 1),
#  ('shawn', 1),
#  ('algonquin', 1),
#  ('leigh', 1),
#  ('crowninshield', 1),
#  ('rudolph', 1),
#  ('humorist', 1),
#  ('official', 1),
#  ('selection', 1),
#  ('wallace', 1),
#  ('actresspeter', 1),
#  ('vicious', 1),
#  ('round', 1),
#  ('national', 1),
#  ('critical', 1),
#  ('circle', 1),
#  ('grandson', 1),
#  ('manhattans', 1),
#  ('romanticdrama', 1),
#  ('cabiria', 1),
#  ('fellinis', 1),
#  ('somebody', 1),
#  ('inspired', 1),
#  ('nights', 1),
#  ('venice', 1),
#  ('international', 1),
#  ('federico', 1),
#  ('rockwell', 1),
#  ('entered', 1),
#  ('alexandre', 1),
#  ('fault', 1),
#  ('faucet', 1),
#  ('tommy', 1),
#  ('jurors', 1),
#  ('bishop', 1),
#  ('jury', 1),
#  ('polystyrene', 1),
#  ('wayne', 1),
#  ('guilty', 1),
#  ('suite', 1),
#  ('staying', 1),
#  ('library', 1),
#  ('park', 1),
#  ('jimmy', 1),
#  ('junior', 1),
#  ('little', 1),
#  ('ronnie', 1),
#  ('bev', 1),
#  ('cars', 1),
#  ('brown', 1),
#  ('browns', 1),
#  ('jimmys', 1),
#  ('ronnies', 1),
#  ('rosie', 1),
#  ('stolen', 1),
#  ('meeting', 1),
#  ('cakes', 1),
#  ('bevs', 1),
#  ('omar', 1),
#  ('arrest', 1),
#  ('arrive', 1),
#  ('navy', 1),
#  ('anton', 1),
#  ('kari', 1),
#  ('conrad', 1),
#  ('sankothe', 1),
#  ('wuhrer', 1),
#  ('eldard', 1),
#  ('composed', 1),
#  ('ron', 1),
#  ('slovin', 1),
#  ('modern', 1),
#  ('pregnant', 1),
#  ('sperm', 1),
#  ('grace', 1),
#  ('intimacy', 1),
#  ('commitment', 1),
#  ('lisa', 1),
#  ('eichhorn', 1),
#  ('feature', 1),
#  ('elaine', 1),
#  ('advice', 1),
#  ('rhodes', 1),
#  ('parenthooda', 1),
#  ('rocked', 1),
#  ('sister', 1),
#  ('prove', 1),
#  ('confront', 1),
#  ('schreiber', 1),
#  ('posey', 1),
#  ('davis', 1),
#  ('jos', 1),
#  ('station', 1),
#  ('hope', 1),
#  ('mcnamara', 1),
#  ('pat', 1),
#  ('secondo', 1),
#  ('primo', 1),
#  ('restaurant', 1),
#  ('pascal', 1),
#  ('brothers', 1),
#  ('prima', 1),
#  ('paradise', 1),
#  ('gabriella', 1),
#  ('primos', 1),
#  ('singer', 1),
#  ('singers', 1),
#  ('magnificent', 1),
#  ('admits', 1),
#  ('secondos', 1),
#  ('dish', 1),
#  ('italian', 1),
#  ('beach', 1),
#  ('offer', 1),
#  ('fay', 1),
#  ('harrys', 1),
#  ('ceremony', 1),
#  ('lucy', 1),
#  ('hilliard', 1),
#  ('cookie', 1),
#  ('university', 1),
#  ('universitys', 1),
#  ('accompany', 1),
#  ('fictional', 1),
#  ('character', 1),
#  ('latest', 1),
#  ('crystal', 1),
#  ('sexobsessed', 1),
#  ('keith', 1),
#  ('crime', 1),
#  ('wartime', 1),
#  ('reddin', 1),
#  ('adaptation', 1),
#  ('dunsky', 1),
#  ('alarmist', 1),
#  ('reynolds', 1),
#  ('arquette', 1),
#  ('evan', 1),
#  ('capshaw', 1),
#  ('fatherinlaw', 1),
#  ('celine', 1),
#  ('robert', 1),
#  ('jackson', 1),
#  ('oreilly', 1),
#  ('naville', 1),
#  ('runs', 1),
#  ('mayhew', 1),
#  ('gabriel', 1),
#  ('bar', 1),
#  ('roberts', 1),
#  ('knocks', 1),
#  ('angels', 1),
#  ('drive', 1),
#  ('elliott', 1),
#  ('woods', 1),
#  ('poem', 1),
#  ('says', 1),
#  ('heart', 1),
#  ('file', 1),
#  ('etruscan', 1),
#  ('girls', 1),
#  ('scientist', 1),
#  ('dead', 1),
#  ('perfect', 1),
#  ('america', 1),
#  ('experiments', 1),
#  ('eighteen', 1),
#  ('mysterious', 1),
#  ('turns', 1),
#  ('biologically', 1),
#  ('artificially', 1),
#  ('beings', 1),
#  ('rise', 1),
#  ('secret', 1),
#  ('north', 1),
#  ('physically', 1),
#  ('sect', 1),
#  ('kitty', 1),
#  ('claire', 1),
#  ('targeted', 1),
#  ('retrieving', 1),
#  ('kyra', 1),
#  ('sedgwick', 1),
#  ('ethan', 1),
#  ('robin', 1),
#  ('tunney', 1),
#  ('embry', 1),
#  ('tracks', 1),
#  ('coltrane', 1),
#  ('incompetent', 1),
#  ('level', 1),
#  ('low', 1),
#  ('runaway', 1),
#  ('robbie', 1),
#  ('burtom', 1),
#  ('tennis', 1),
#  ('stowaways', 1),
#  ('diverse', 1),
#  ('crooner', 1),
#  ('hide', 1),
#  ('happy', 1),
#  ('buscemi', 1),
#  ('language', 1),
#  ('duo', 1),
#  ('moremistaken', 1),
#  ('franks', 1),
#  ('bomber', 1),
#  ('confrontation', 1),
#  ('sobs', 1),
#  ('ensue', 1),
#  ('swindles', 1),
#  ('practicing', 1),
#  ('platt', 1),
#  ('mad', 1),
#  ('titania', 1),
#  ('oberon', 1),
#  ('demetrius', 1),
#  ('hermia', 1),
#  ('lysander', 1),
#  ('helena', 1),
#  ('forest', 1),
#  ('puck', 1),
#  ('tragedy', 1),
#  ('troupe', 1),
#  ('duke', 1),
#  ('fairies', 1),
#  ('desperately', 1),
#  ('seen', 1),
#  ('bower', 1),
#  ('tires', 1),
#  ('wander', 1),
#  ('rehearsal', 1),
#  ('athena', 1),
#  ('woos', 1),
#  ('unintentionally', 1),
#  ('cole', 1),
#  ('gittens', 1),
#  ('undercover', 1),
#  ('reid', 1),
#  ('dambrosio', 1),
#  ('myra', 1),
#  ('breezy', 1),
#  ('superiors', 1),
#  ('god', 1),
#  ('officers', 1),
#  ('unhinged', 1),
#  ('coles', 1),
#  ('cop', 1),
#  ('members', 1),
#  ('drug', 1),
#  ('connelly', 1),
#  ('empire', 1),
#  ('gould', 1),
#  ('mitchell', 1),
#  ('joe', 1),
#  ('demanding', 1),
#  ('opus', 1),
#  ('bearded', 1),
#  ('mans', 1),
#  ('colorful', 1),
#  ('portfolio', 1),
#  ('perceptive', 1),
#  ('times', 1),
#  ('wanders', 1),
#  ('sweet', 1),
#  ('daughters', 1),
#  ('obnoxious', 1),
#  ('greenwich', 1),
#  ('hes', 1),
#  ('collecting', 1),
#  ('support', 1),
#  ('merely', 1),
#  ('occasional', 1),
#  ('founder', 1),
#  ('gwen', 1),
#  ('kiki', 1),
#  ('lee', 1),
#  ('press', 1),
#  ('hector', 1),
#  ('weidmann', 1),
#  ('junket', 1),
#  ('gwens', 1),
#  ('eddies', 1),
#  ('convince', 1),
#  ('believes', 1),
#  ('career', 1),
#  ('stories', 1),
#  ('portrayed', 1),
#  ('weidmanns', 1),
#  ('bridget', 1),
#  ('retired', 1),
#  ('role', 1),
#  ('appeared', 1),
#  ('movies', 1),
#  ('television', 1),
#  ('americancanadian', 1),
#  ('zaloom', 1),
#  ('theatrical', 1),
#  ('fonda', 1),
#  ('fondas', 1),
#  ('shebang', 1),
#  ('giancarlo', 1),
#  ('gianninithis', 1),
#  ('eliot', 1),
#  ('arthur', 1),
#  ('snake', 1),
#  ('puggy', 1),
#  ('jenny', 1),
#  ('matt', 1),
#  ('herk', 1),
#  ('matts', 1),
#  ('romero', 1),
#  ('agents', 1),
#  ('miami', 1),
#  ('hitmen', 1),
#  ('suitcase', 1),
#  ('door', 1),
#  ('handcuffed', 1),
#  ('rooney', 1),
#  ('connor', 1),
#  ('maguire', 1),
#  ('jr', 1),
#  ('mcgovern', 1),
#  ('rooneys', 1),
#  ('sons', 1),
#  ('nitti', 1),
#  ('calvino', 1),
#  ('sends', 1),
#  ('sullivans', 1),
#  ('rance', 1),
#  ('drives', 1),
#  ('capones', 1),
#  ('marisa', 1),
#  ('caroline', 1),
#  ('ty', 1),
#  ('lane', 1),
#  ('management', 1),
#  ('stephanie', 1),
#  ('lionel', 1),
#  ('maid', 1),
#  ('spends', 1),
#  ('promoted', 1),
#  ('nixon', 1),
#  ('lunch', 1),
#  ('coat', 1),
#  ('jerry', 1),
#  ('dinner', 1),
#  ('spend', 1),
#  ('core', 1),
#  ('keyes', 1),
#  ('virgil', 1),
#  ('finch', 1),
#  ('compartment', 1),
#  ('destini', 1),
#  ('restart', 1),
#  ('rotation', 1),
#  ('zimsky', 1),
#  ('vessel', 1),
#  ('energy', 1),
#  ('surface', 1),
#  ('cores', 1),
#  ...]

# %% [markdown]
# Through this I found that there were some words repeated like film and directed. However, there was not a strong enough cut off when just looking at the list for me to add new stop words into my corpus. This can be further looked at later.
